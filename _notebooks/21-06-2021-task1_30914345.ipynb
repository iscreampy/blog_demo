# %% [markdown]
# # FIT5196 Task 1 in Assessment 1
# #### Student Name: Dinesh Kesaboina
# #### Student ID: 30914345
#
# Date: 13/09/2020
#
# Version: 1.0
#
# Environment: Python 3.7.3 and Jupyter notebook
#
# Libraries used: please include the main libraries you used in your assignment here, e.g.,:
# * os (for OS related functionality, eg: read and write operations, included in Anaconda Python 3.7.3)
# * re (for regular expression, included in Anaconda Python 3.7.3)
# * langid (for language classification, <b> not </b> included in Anaconda Python 3.7.3)
#
#
#
# <b><font size=4, color="blue">Note : </font></b>
# * Langid was downloaded from the terminal for this assessement.
# * All analysis and thought process for the development of this project was based on the sample output file. For this reason, the sample file will be used initially for analysis.
# * Finally, the same functions used to process the sample data will be applied on the full data to obtain the XML file output.

# %% [markdown]
# ## 1.  Import libraries

# %% [markdown]
# In this section, you can write your python scripts to parse the correspondiing file.
# You should
# * write proper notes for all code block in this notebook using the Markdown cells
# * provide proper comment in your scripts
# * run all cells to make sure scripts are runable. If the scripts cannot be run by the assessors, they will not be assessed and zero mark will be given to the task.

# %%
# Import librariesarequired the text data analysis
import os 
import langid
from langid import classify
import re

# %% [markdown]
# ## 2. Read files from the directory
# In this section we read all the text files from a given directory. The function ```read_files``` takes an OS file path as the argument and returns a list of text files contained in that file path. Here we use ```os``` package's ```listdir``` method. This method returns the names of all files in the directory contained in a list. Next, we use ```os.path``` module's ```join``` method to join the file path and file name to access each text file. We then proceed to check if a given file is a regular file and if it is a text file using the aforementioned module's ```isfile``` and ```endswith``` methods respectively.

# %%
def read_files(file_path):
    """Function returns a list of texts containing all the text files in a file path

    Args:
        file_path (str, mandatory) : Path to a file directory.

    Returns:
        list : List of texts in a directory
    """
    list_of_texts = []
    for txt_file in os.listdir(file_path): 
        txt_file = os.path.join(file_path, txt_file)
        if os.path.isfile(txt_file) and txt_file.endswith('.txt'): 
            with open(txt_file, "r") as file:
                content = file.read()
                list_of_texts.append(content)
    return list_of_texts

# Read all files from 
file_path_sample = './part1/'
sample_data = read_files(file_path_sample)

# %%
print(f"There are {len(sample_data)} text files in the list. \
There are of the type {type(sample_data[0])}")
# Out:
# There are 13 text files in the list. There are of the type <class 'str'>

# %%
sample_data[0]
# Out:
# '{"data":[{"created_at":"2020-05-07T12:05:43.000Z","id":"1258367403953500164","text":"@thehill Trump’s Ridiculous Behavior about Covid19 at Pandemic Briefings Battles https://t.co/4Gjy5tQ4XI https://t.co/8vcxU75Nz4"},{"created_at":"2020-05-07T12:05:43.000Z","id":"1258367404029153280","text":"Coronavirus : le plan pour la culture d\'Emmanuel Macron https://t.co/0vUpUoXC1O"},{"created_at":"2020-05-07T12:05:43.000Z","id":"1258367405157466112","text":"‘Complacent’ UK draws global criticism for Covid-19 response https://t.co/Qmd2GSQPY5"},{"created_at":"2020-05-07T12:05:43.000Z","id":"1258367406243745792","text":"Quatro hospitais particulares de Fortaleza estão com capacidade esgotada na urgência e emergência | Coronavírus - Últimas Notícias sobre o Coronavírus | O POVO Online https://t.co/y9w5t4Dbs9"},{"created_at":"2020-05-07T12:05:43.000Z","id":"1258367406285762560","text":"@Eglisecatho @Diocese72 +55 (22)981565421\\nDon\'t you have a BRAIN?\\nOnly (martial law)HOME PRISON, during 30 days, of all(100%) CITIZENS will stop CORONA VIRUS.\\nNo more deaths.\\nThe economy will be normal in 30 days too.\\n CURE See Dra Eunara Negri discovered the CURE of CORONAVIRUS.\\nhttps://t.co/2uLsT6Eehn"},{"created_at":"2020-05-07T12:05:43.000Z","id":"1258367406344474625","text":"#coronavirus: Atriz Daisy Lúcidi morre de Covid-19 aos 90 anos\\"  https://t.co/GsmFOB4OE4"},{"created_at":"2020-05-07T12:05:43.000Z","id":"1258367407606960129","text":"UK contact-tracing app could fall foul of privacy law, government told\\n\\nhttps://t.co/W85NfMKadm"},{"created_at":"2020-05-07T12:05:43.000Z","id":"1258367407653040133","text":"Do you want to be up to date with #coronavirus worldwide? It is a good idea to attach this \\uD83D\\uDC47 page to your sources. https://t.co/1mh5p6IQFz"},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367407770472449","text":"2 Utah County businesses told staff to ignore COVID-19 guidelines, resulting in 68 positive cases | Local News | https://t.co/XhYEBoqOfJ https://t.co/q33WGNwikg"},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367408252817410","text":"Are 2 mahine me kitni baar fake news doge https://t.co/esxocgOQ1D"},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367408504528896","text":"@girlsreallyrule @joncoopertweets Speaking of investigations about bungled responses to the pandemic, there needs to be an investigation into the Trump Administration’s atrocious mismanagement of COVID19 in the USA."},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367408508743680","text":"Listen to this man all the way to the end. https://t.co/ttDtR278nG"},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367408689033217","text":"@CortesSteve Cook Country #Democrats, especially @chicagosmayor &amp; @ToniPreckwinkle, will \\"goose\\" step w/@GovPritzker, but - MANY counties around #Illinois that aren\'t so in bed with #Dems, where #Covid19/#CoronaVirus isn\'t so prevalent, should revolt &amp; start to #reopenillinois, safely. #twill"},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367408923914241","text":"@realDonaldTrump, @WhiteHouse Why can’t we see the #CDC #COVID19 recommendations? What are you hiding? https://t.co/SVeFHfsHmW"},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367409292894208","text":"#KASARAGOD \\n#KERALAHEALTHDEPARTMENT https://t.co/aKt7C9RQpz"},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367410568036352","text":"@HillaryClinton How is trump “winding down” when people are still dying and we’re still quarantined? There’s still no immunization against this flu. Coronavirus isn’t taken as serious as it should. This is the first pandemic of the digital age and it’s not over!"},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367410781876224","text":"As we bail out highly leveraged corporations and oil which was heading south prior to virus https://t.co/0onTRbY5Mn"},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367411243421696","text":"Yelp and Shopify release omni-channel updates during CO ...

# %% [markdown]
# ## 3. Extract the data tag
# We need to extract just the data tag from our text files. In order to extract just that part from the data which is in string format, we write a regex pattern to extract this data.
#
# <br>
# <center><b><font size=5, color="blue"> Regex explanation </font></b></center>
# <br>
#
#
# * ```data_pattern = r'''(?<="data":)\[\{.*\:.*\}\]\,'''```
#
#
# This regex is designed keeping mind that the data tag starts with a ``` [{ ``` and has some character data followed by a ```:``` (colon) followed by more charcters (```.``` matches any character). We take advantage of the fact that the data tag ends with ```}],``` to design our regex. Notice that we escape the special characters (known as metacharacters) using a backslash.
#
# Following the creation of this regex, we use ```re``` module's ```search``` method. This method looks through a string and finds the first occurrence of a pattern. As data tag appears only once in each file, this is appropriate.

# %%
def grab_data_tag(list_of_texts):
    """Function returns a list of strings containing all the data tags in the text files

    Args:
        list_of_texts (list, mandatory): List containing all files which are in string format
    
    Returns:
    list: list containing all the data tags for each file
    """
    tweet_data = []
    for text in list_of_texts:
        
        # create date regex to match in text
        data_pattern = r'''(?<="data":)\[\{.*\:.*\}\]\,'''
        matches = re.search(data_pattern, text)
        
        # Remove the last comma at the end
        _data = matches.group()[:-1]
        tweet_data.append(_data)
    
    assert len(list_of_texts) == len(tweet_data), "The number of files does not equal the \
                                                    equal the number of data tags!"
    
    return tweet_data

# test
tweet_data_sample = grab_data_tag(sample_data)

# %%
# delete this 
len(tweet_data_sample) == len(sample_data)
# Out:
# True

# %% [markdown]
# ## 4. Parse text data
# As we can see that from the previous cell, the files in our data are in <b>string</b> format. Let's take a closer look at the first list element.

# %%
tweet_data_sample[0]
# Out:
# '[{"created_at":"2020-05-07T12:05:43.000Z","id":"1258367403953500164","text":"@thehill Trump’s Ridiculous Behavior about Covid19 at Pandemic Briefings Battles https://t.co/4Gjy5tQ4XI https://t.co/8vcxU75Nz4"},{"created_at":"2020-05-07T12:05:43.000Z","id":"1258367404029153280","text":"Coronavirus : le plan pour la culture d\'Emmanuel Macron https://t.co/0vUpUoXC1O"},{"created_at":"2020-05-07T12:05:43.000Z","id":"1258367405157466112","text":"‘Complacent’ UK draws global criticism for Covid-19 response https://t.co/Qmd2GSQPY5"},{"created_at":"2020-05-07T12:05:43.000Z","id":"1258367406243745792","text":"Quatro hospitais particulares de Fortaleza estão com capacidade esgotada na urgência e emergência | Coronavírus - Últimas Notícias sobre o Coronavírus | O POVO Online https://t.co/y9w5t4Dbs9"},{"created_at":"2020-05-07T12:05:43.000Z","id":"1258367406285762560","text":"@Eglisecatho @Diocese72 +55 (22)981565421\\nDon\'t you have a BRAIN?\\nOnly (martial law)HOME PRISON, during 30 days, of all(100%) CITIZENS will stop CORONA VIRUS.\\nNo more deaths.\\nThe economy will be normal in 30 days too.\\n CURE See Dra Eunara Negri discovered the CURE of CORONAVIRUS.\\nhttps://t.co/2uLsT6Eehn"},{"created_at":"2020-05-07T12:05:43.000Z","id":"1258367406344474625","text":"#coronavirus: Atriz Daisy Lúcidi morre de Covid-19 aos 90 anos\\"  https://t.co/GsmFOB4OE4"},{"created_at":"2020-05-07T12:05:43.000Z","id":"1258367407606960129","text":"UK contact-tracing app could fall foul of privacy law, government told\\n\\nhttps://t.co/W85NfMKadm"},{"created_at":"2020-05-07T12:05:43.000Z","id":"1258367407653040133","text":"Do you want to be up to date with #coronavirus worldwide? It is a good idea to attach this \\uD83D\\uDC47 page to your sources. https://t.co/1mh5p6IQFz"},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367407770472449","text":"2 Utah County businesses told staff to ignore COVID-19 guidelines, resulting in 68 positive cases | Local News | https://t.co/XhYEBoqOfJ https://t.co/q33WGNwikg"},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367408252817410","text":"Are 2 mahine me kitni baar fake news doge https://t.co/esxocgOQ1D"},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367408504528896","text":"@girlsreallyrule @joncoopertweets Speaking of investigations about bungled responses to the pandemic, there needs to be an investigation into the Trump Administration’s atrocious mismanagement of COVID19 in the USA."},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367408508743680","text":"Listen to this man all the way to the end. https://t.co/ttDtR278nG"},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367408689033217","text":"@CortesSteve Cook Country #Democrats, especially @chicagosmayor &amp; @ToniPreckwinkle, will \\"goose\\" step w/@GovPritzker, but - MANY counties around #Illinois that aren\'t so in bed with #Dems, where #Covid19/#CoronaVirus isn\'t so prevalent, should revolt &amp; start to #reopenillinois, safely. #twill"},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367408923914241","text":"@realDonaldTrump, @WhiteHouse Why can’t we see the #CDC #COVID19 recommendations? What are you hiding? https://t.co/SVeFHfsHmW"},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367409292894208","text":"#KASARAGOD \\n#KERALAHEALTHDEPARTMENT https://t.co/aKt7C9RQpz"},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367410568036352","text":"@HillaryClinton How is trump “winding down” when people are still dying and we’re still quarantined? There’s still no immunization against this flu. Coronavirus isn’t taken as serious as it should. This is the first pandemic of the digital age and it’s not over!"},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367410781876224","text":"As we bail out highly leveraged corporations and oil which was heading south prior to virus https://t.co/0onTRbY5Mn"},{"created_at":"2020-05-07T12:05:44.000Z","id":"1258367411243421696","text":"Yelp and Shopify release omni-channel updates during COVID-19 h ...

# %% [markdown]
# From examining the file, we see that it has two tags : ```data``` and ```errors```. We now need to parse this text to extract textual information from this data. In order to do that, we create four functions :
#
# * ```get_tweet_ids```: Get all the ids from the text
# * ```get_tweet_texts```: Get all the texts from the text
# * ```get_tweet_timedates```: Get all the dates and times from the text
# * ```get_full_tweets```: Create a full tweet dictionary using the above functions
#
# <br>
# <center><b><font size=5, color="blue"> Regex explanation </font></b></center>
# <br>
#
#
# * ```id_pattern = r'(?P<id>(?<="id":\")\d+(?=\"))'```
#
#
# In order to extract the ids from all the texts we use a named group called ```id``` to capture all the text ids. We use a <b>positive look behind</b> to get the text appears after ```"id":```, we then match one or more digits followed by a <b>positive look ahead</b> that looks for a ```"```(quotation mark) ahead of the match. Note that we escape the question mark using a backslash( \\ ).
#
#
# * ```(?P<text>(?<="text":\")[^"].*?(?=\"[,}][^\s\d]))```
#
#
# In order to extract the texts data from all the texts we use a named group called ```text``` to capture all the text data.We use a <b>positive look behind</b> to get the string appearing after ```"text":```, we then match one or more characters that are not quotation marks, we do this using a <b>negated character class</b>. Note the use of question mark( ? )to implement this lazily. We then implement a <b>positive look ahead</b> to look for either a ```"```(quotation mark) or ```}```(closing curly brace) ahead of the match. This is implemented using a character class(square brackets) followed by the  negated character class which matches to anything other than a space and a digit. This last part helps us account for texts in the data which have mutiple quotation marks.
#
#
# * ```r'(?P<created_at>(?<="created_at":\")(?:[12]\d{3}-(?:0[1-9]|1[0-2])-(?:0[1-9]|[12]\d|3[01])T[0-2]\d:\d{2}:\d{2}.000Z)(?=\"))'```
#
#
# In order to extract the texts data from all the texts we use a named group called ```created_at``` to capture all the datetime data.We use a <b>positive look behind</b> to get the text preceded by ```"created_at":```, followed by a <b>non-capturing group</b> that matches either 1 or 2 as the first digit followed by three digits, then a hyphen. The next non-capturing group captures two digit numbers such in the range 01-12 using the <b>alternation</b> to choose between 01-09 range and 10-12 range. This is done to match the 12 months of the year. After the next hyphen(literal match) we create another non-capturing group which captures two digits in the range 01-31. Note the use of character classes and alternations to implement this regex. This is followed by T (literal match) and a range of 0-2 implemented in a character class. This is follwowed by a simple regex pattern to capture the rest of the datetime format. Note that this regex is designed to capture any legitimate date. For this assessment we could have matched the literal ```2020``` after ```created_at:``` but this was not done to enable reusability of regexes.

# %%
def get_tweet_ids(tweet_file):
    """Function returns a list of ids containing all the tweet ids in the text

    Args:
        tweet_file (str, mandatory) : a text string from which ids need to be extracted.

    Returns:
        list : List of ids in a text"""
    
    # create and compile a regex
    id_pattern = r'(?P<id>(?<="id":\")\d+(?=\"))'
    regx = re.compile(id_pattern)
    
    # create a list of matched dictionaries
    id_list = [m.groupdict() for m in regx.finditer(tweet_file)]
    
    return id_list

# test
id_matches = get_tweet_ids(tweet_data_sample[0])
print(f"The first id of the text is : {id_matches[0]['id']}")
# Out:
# The first id of the text is : 1258367403953500164

# %%
def get_tweet_texts(tweet_file):
    """Function returns a list of texts containing all the tweet texts in the text

    Args:
        tweet_file (str, mandatory) : a tweet string from which text need to be extracted.

    Returns:
        list : List of texts in a tweet text"""
    
    # create and compile a regex
    text_pattern = r'(?P<text>(?<="text":\")[^"].*?(?=\"[,}][^\s\d]))'
    regx = re.compile(text_pattern)
    
    # create a list of matched dictionaries
    text_list = [m.groupdict() for m in regx.finditer(tweet_file)]
    
    return text_list

# test
text_matches = get_tweet_texts(tweet_data_sample[0])
print(f"The first text is : {text_matches[0]['text']}")
# Out:
# The first text is : @thehill Trump’s Ridiculous Behavior about Covid19 at Pandemic Briefings Battles https://t.co/4Gjy5tQ4XI https://t.co/8vcxU75Nz4

# %%
def get_tweet_timedates(tweet_file):
    """Function returns a list of texts containing all the tweet texts in the text

    Args:
        tweet_file (str, mandatory) : a tweet string from which text need to be extracted.

    Returns:
        list : List of texts in a tweet text"""
    
    # create and compile a regex
    created_at_pattern = r'(?P<created_at>(?<="created_at":\")(?:[12]\d{3}-(?:0[1-9]|1[0-2])-(?:0[1-9]|[12]\d|3[01])T[0-2]\d:\d{2}:\d{2}.000Z)(?=\"))'
    regx = re.compile(created_at_pattern)
    
    # create a list of matched dictionaries
    datetime_list = [m.groupdict() for m in regx.finditer(tweet_file)]
    
    return datetime_list

# test
datetime_matches = get_tweet_timedates(tweet_data_sample[0])
print(f"The first text is : {datetime_matches[0]['created_at']}")
# Out:
# The first text is : 2020-05-07T12:05:43.000Z

# %% [markdown]
# In all the above functions note the use of ```matchobject.groupdict()``` method which returns a dictionary of the named group as key and the match object as the value. The regexes were designed to take advantage of this method from the ```re``` package (hence the use of named dictionaries in the regexes).
#
# In the function below we use the three dictionaries we obtain from the above functions to recreate each tweet as a list of dictionaries. We make sure to check using Python's ```assert``` that each dictionary is of the same length to ensure we matching the appropriate id, created_at and text together. Incase the lengths are not matching an ```AssertionError``` is thrown with the file number that is causing the issue.

# %%
def get_full_tweets(tweet_data):
    """Function returns a list of texts containing all the tweet texts in the text

    Args:
        tweet_file (str, mandatory) : a tweet string from which text need to be extracted.

    Returns:
        list : List of dictionary containing tweets"""
    
    # Initiate an empty list to capture all the tweets
    # file_num keeps track of file number for debugging purposes
    tweet_list = []
    file_num = 0
    
    # Iterate through each file
    for tweet_file in tweet_data:
        file_num += 1
        id_matches = get_tweet_ids(tweet_file)
        text_matches = get_tweet_texts(tweet_file)
        datetime_matches = get_tweet_timedates(tweet_file)
        
        # Make sure all lengths match
        # If they don't use the file number in the error for debugging
        assert len(id_matches) == len(text_matches) == len(datetime_matches), f"length not the same! check file index : {file_num+1}"
        
        # Append the other two dictionaries to one dictionary from above
        # We append text_matches and datetime_matches to id_matches dictionary
        for i in range(len(id_matches)):
            id_matches[i].update(text_matches[i])
            id_matches[i].update(datetime_matches[i])
        tweet_list.append(id_matches)
        
    return tweet_list

# Test
tweets_sample = get_full_tweets(tweet_data_sample)

# %%
tweets_sample[0]
# Out:
# [{'id': '1258367403953500164',
#   'text': '@thehill Trump’s Ridiculous Behavior about Covid19 at Pandemic Briefings Battles https://t.co/4Gjy5tQ4XI https://t.co/8vcxU75Nz4',
#   'created_at': '2020-05-07T12:05:43.000Z'},
#  {'id': '1258367404029153280',
#   'text': "Coronavirus : le plan pour la culture d'Emmanuel Macron https://t.co/0vUpUoXC1O",
#   'created_at': '2020-05-07T12:05:43.000Z'},
#  {'id': '1258367405157466112',
#   'text': '‘Complacent’ UK draws global criticism for Covid-19 response https://t.co/Qmd2GSQPY5',
#   'created_at': '2020-05-07T12:05:43.000Z'},
#  {'id': '1258367406243745792',
#   'text': 'Quatro hospitais particulares de Fortaleza estão com capacidade esgotada na urgência e emergência | Coronavírus - Últimas Notícias sobre o Coronavírus | O POVO Online https://t.co/y9w5t4Dbs9',
#   'created_at': '2020-05-07T12:05:43.000Z'},
#  {'id': '1258367406285762560',
#   'text': "@Eglisecatho @Diocese72 +55 (22)981565421\\nDon't you have a BRAIN?\\nOnly (martial law)HOME PRISON, during 30 days, of all(100%) CITIZENS will stop CORONA VIRUS.\\nNo more deaths.\\nThe economy will be normal in 30 days too.\\n CURE See Dra Eunara Negri discovered the CURE of CORONAVIRUS.\\nhttps://t.co/2uLsT6Eehn",
#   'created_at': '2020-05-07T12:05:43.000Z'},
#  {'id': '1258367406344474625',
#   'text': '#coronavirus: Atriz Daisy Lúcidi morre de Covid-19 aos 90 anos\\"  https://t.co/GsmFOB4OE4',
#   'created_at': '2020-05-07T12:05:43.000Z'},
#  {'id': '1258367407606960129',
#   'text': 'UK contact-tracing app could fall foul of privacy law, government told\\n\\nhttps://t.co/W85NfMKadm',
#   'created_at': '2020-05-07T12:05:43.000Z'},
#  {'id': '1258367407653040133',
#   'text': 'Do you want to be up to date with #coronavirus worldwide? It is a good idea to attach this \\uD83D\\uDC47 page to your sources. https://t.co/1mh5p6IQFz',
#   'created_at': '2020-05-07T12:05:43.000Z'},
#  {'id': '1258367407770472449',
#   'text': '2 Utah County businesses told staff to ignore COVID-19 guidelines, resulting in 68 positive cases | Local News | https://t.co/XhYEBoqOfJ https://t.co/q33WGNwikg',
#   'created_at': '2020-05-07T12:05:44.000Z'},
#  {'id': '1258367408252817410',
#   'text': 'Are 2 mahine me kitni baar fake news doge https://t.co/esxocgOQ1D',
#   'created_at': '2020-05-07T12:05:44.000Z'},
#  {'id': '1258367408504528896',
#   'text': '@girlsreallyrule @joncoopertweets Speaking of investigations about bungled responses to the pandemic, there needs to be an investigation into the Trump Administration’s atrocious mismanagement of COVID19 in the USA.',
#   'created_at': '2020-05-07T12:05:44.000Z'},
#  {'id': '1258367408508743680',
#   'text': 'Listen to this man all the way to the end. https://t.co/ttDtR278nG',
#   'created_at': '2020-05-07T12:05:44.000Z'},
#  {'id': '1258367408689033217',
#   'text': '@CortesSteve Cook Country #Democrats, especially @chicagosmayor &amp; @ToniPreckwinkle, will \\"goose\\" step w/@GovPritzker, but - MANY counties around #Illinois that aren\'t so in bed with #Dems, where #Covid19/#CoronaVirus isn\'t so prevalent, should revolt &amp; start to #reopenillinois, safely. #twill',
#   'created_at': '2020-05-07T12:05:44.000Z'},
#  {'id': '1258367408923914241',
#   'text': '@realDonaldTrump, @WhiteHouse Why can’t we see the #CDC #COVID19 recommendations? What are you hiding? https://t.co/SVeFHfsHmW',
#   'created_at': '2020-05-07T12:05:44.000Z'},
#  {'id': '1258367409292894208',
#   'text': '#KASARAGOD \\n#KERALAHEALTHDEPARTMENT https://t.co/aKt7C9RQpz',
#   'created_at': '2020-05-07T12:05:44.000Z'},
#  {'id': '1258367410568036352',
#   'text': '@HillaryClinton How is trump “winding down” when people are still dying and we’re still quarantined? There’s still no immunization against this flu. Coronavirus isn’t taken as serious as it should. This is the first pandemic of the digital age and it’s not over!',
#   'created_at': '2020-05-07T12:05:44.000Z'},
#  {'id': '1258367410781876224',
#   'text': 'As we bail out highly leveraged corporations and oil which was heading south prior to virus https://t.co/0onTRbY5Mn',
#   'created_at': '2020-05-07T12:05:44.000Z'},
#  {'id': '1258367411243421696',
#   'text': 'Yelp and Shopify release omni-channel updates during COVID-19 https://t.co/KxLDOpPBCC #markedsføring https://t.co/2k067w47cG',
#   'created_at': '2020-05-07T12:05:44.000Z'},
#  {'id': '1258367411406934016',
#   'text': "#Espagne Anomalie démocratique, crimes franquistes, impunité. L'ancien policier espagnol, Antonio González Pacheco, connu comme Billy el Niño, est décédé du Covid-19. Ce tortionnaire n'a jamais été jugé et a même été décoré pendant la période démocratique. https://t.co/gIxwiNyPme",
#   'created_at': '2020-05-07T12:05:44.000Z'},
#  {'id': '1258367411495018498',
#   'text': 'Atriz e radialista Daisy Lúcidi morre por Covid-19 aos 90 anos\\n#COVIDー19 #coronavirus #coronavirusnobrasil\\n\\n- Mais notícias no #RedeTVNews, às 19h30\\nhttps://t.co/TR4uAqITZ1',
#   'created_at': '2020-05-07T12:05:44.000Z'},
#  {'id': '1258367412359086080',
#   'text': '@ababybIue pior é quando falam \\"ah mas já viu que muita gente que morre de outra coisa eles colocam que é coronavirus?\\" eu não tenho mais paciência',
#   'created_at': '2020-05-07T12:05:45.000Z'},
#  {'id': '1258367412484931586',
#   'text': '#TrumpGenocide https://t.co/4w2xUe1hMe',
#   'created_at': '2020-05-07T12:05:45.000Z'},
#  {'id': '1258367412543590400',
#   'text': '@10DowningStreet please take note! https://t.co/Gb7tT4hqfn',
#   'created_at': '2020-05-07T12:05:45.000Z'},
#  {'id': '1258367412778524672',
#   'text': 'Jaime Bofill highlights financial measures by #Spain &amp; #eu to shield companies from economic effects of #covid19 #financialinstitutions #financialregulation https://t.co/fVKUkCynmC',
#   'created_at': '2020-05-07T12:05:45.000Z'},
#  {'id': '1258367412786864131',
#   'text': 'New study reveals most Europeans support basic income after COVID-19 | University of Oxford https://t.co/kLywpLSS5o',
#   'created_at': '2020-05-07T12:05:45.000Z'},
#  {'id': '1258367412799508480',
#   'text': 'I don’t trust the UN so maybe Assange should be moved to the US? \\uD83E\\uDD14 https://t.co/AUDL3P2jfT',
#   'created_at': '2020-05-07T12:05:45.000Z'},
#  {'id': '1258367412891770880',
#   'text': '@cjohansen_MT @goldiett7 @R_ZenBo But didn’t you worry about the servers of the food and how that could be unwittingly spreading covid19? We are avoiding dining in restaurants.',
#   'created_at': '2020-05-07T12:05:45.000Z'},
#  {'id': '1258367412904382464',
#   'text': 'Apple Awards $10 Million to COVID-19 Testing Kit Maker From Advanced Manufacturing Fund. I Hate Everything.',
#   'created_at': '2020-05-07T12:05:45.000Z'},
#  {'id': '1258367413524918273',
#   'text': 'So great to see @clubmaseratixxx in the latest update from @Brazzers and that too with @MarkusDupree ! Hope to see more of @BbwSofiaRose @MillyMarksxxx and @spitneyspears too ! #ThursdayThoughts #NursesDay2020 #BBW #COVID19 #Faptastic ! https://t.co/RIvpdHv2Kj',
#   'created_at': '2020-05-07T12:05:45.000Z'},
#  {'id': '1258367414590472195',
#   'text': 'This is a great step in the right direction. Can we also stop the private sale of non #COVID19 test kids and the public sale of all test kids?!?! In fact, stop the sale of all kids, public or private!!! #kidsarepeopletoo #wellsorta #oknotreally #butalmost https://t.co/P2Si5ufZOf',
#   'created_at': '2020-05-07T12:05:45.000Z'},
#  {'id': '1258367415080988672',
#   'text': '@CNN UK has reported more than 30,000 deaths, highest in Europe\\n\\nLatest updates | # cases per million population\\uD83D\\uDC47\\n\\nhttps://t.co/TqfSuFkkLd\\n#COVID19 #Covid_19',
#   'created_at': '2020-05-07T12:05:45.000Z'},
#  {'id': '1258367415534202880',
#   'text': 'European Union https://t.co/uAeXCUxxRJ  @bronzino70 #madonna #coronavirus',
#   'created_at': '2020-05-07T12:05:45.000Z'},
#  {'id': '1258367415559368710',
#   'text': 'Due to #COVID19 aka #Coronavirus Ill be sending the first 350 people that like &amp; retweet this up to $3000 through cashapp, apple pay, paypal or zelle (Must DM ME cashapp name or phone number first) https://t.co/PXLwZuNHRe',
#   'created_at': '2020-05-07T12:05:45.000Z'},
#  {'id': '1258367415672606720',
#   'text': "@BettGunther Your pretty picture does NOT accurately reflect WHO advice...you know that but it doesn't fit your story...  https://t.co/aTHxfMCcZG",
#   'created_at': '2020-05-07T12:05:45.000Z'},
#  {'id': '1258367415806832640',
#   'text': 'Outsourcing the coronavirus crisis to business has failed – and NHS staff know it https://t.co/QOEJWb49Eu',
#   'created_at': '2020-05-07T12:05:45.000Z'},
#  {'id': '1258367416100425728',
#   'text': 'Debido al coronavirus, no habrá @Rsierramorena en 2020 https://t.co/nxIMrMBTxg',
#   'created_at': '2020-05-07T12:05:45.000Z'},
#  {'id': '1258367416456921090',
#   'text': 'الله يعين.. https://t.co/rDXuwR1Kjt',
#   'created_at': '2020-05-07T12:05:46.000Z'},
#  {'id': '1258367416507088897',
#   'text': '\\uD83D\\uDE1F\\uD83D\\uDE1F https://t.co/isV0XGTD7p',
#   'created_at': '2020-05-07T12:05:46.000Z'},
#  {'id': '1258367416528187393',
#   'text': '#desenho  #ilustracion  #Noticias  #COVID19  #coronavirus  https://t.co/5U5lfH9VTB',
#   'created_at': '2020-05-07T12:05:46.000Z'},
#  {'id': '1258367416830234625',
#   'text': 'BBC News - \\"Men with advanced prostate #cancer can take highly targeted hormone therapies at home instead of coming into hospital for chemotherapy, @NHSEngland says\\" - https://t.co/XYTzZIlOTP\\n@ProstateUK @NewbCancerCare @macmillancancer @HealthwatchE @PHE_uk @KennetRadio #covid19',
#   'created_at': '2020-05-07T12:05:46.000Z'},
#  {'id': '1258367416834363393',
#   'text': 'Only a fool\\uD83E\\uDD25or a clown\\uD83E\\uDD21 think like this!\\uD83E\\uDD23\\uD83E\\uDD23 https://t.co/DEFo0a20jP',
#   'created_at': '2020-05-07T12:05:46.000Z'},
#  {'id': '1258367419090944000',
#   'text': 'When you’re bored and @starboyterri  -#OJORO  comes up #coronavirusghana #level3 #lockdownextension #istandwithbuhari #COVID19 https://t.co/F1mGMAj8Ao',
#   'created_at': '2020-05-07T12:05:46.000Z'},
#  {'id': '1258367419170488320',
#   'text': '@Breaking911 Kalifornistan wants America to backfill its Corona deficit. Be cautious, everyone who passes will become a virus death, any red ledger problems will be due to Covid19.',
#   'created_at': '2020-05-07T12:05:46.000Z'},
#  {'id': '1258367419233570816',
#   'text': 'Trump’s New Coronavirus Message: Time to Move On to the Economic Recovery https://t.co/9cU0UIjt9N',
#   'created_at': '2020-05-07T12:05:46.000Z'},
#  {'id': '1258367419497828353',
#   'text': 'BOMBSHELL! CBS News Caught Staging \\"Fake Patient\\" in COVID-19 Testing https://t.co/UrwXyeHc7O',
#   'created_at': '2020-05-07T12:05:46.000Z'},
#  {'id': '1258367419535458305',
#   'text': '@Belex70 @publizistikon bevor man ein risikoreiches Massenexperiment im bevölkerungsreichsten Bundesland startet. Lokal könnte man ja verschiedene Öffnungsvarianten durchspielen, um dann nach 2-3 Wochen zu sehen, welche Wirkung sie auf das Covid-19 Geschehen vor Ort haben.',
#   'created_at': '2020-05-07T12:05:46.000Z'},
#  {'id': '1258367419678105601',
#   'text': '@blogdojosias @alefrota77 @UOLNoticias @UOL Todos os brasileiros se ferrando com o coronavirus e Bozo beneficia servidores com o dinheiro dos sofridos contribuintes. É demais. É os malditos generais dão cobertura as insanidades do presidente. https://t.co/Blzv81ZreJ',
#   'created_at': '2020-05-07T12:05:46.000Z'},
#  {'id': '1258367419753664512',
#   'text': 'Coronavirus : que faire des 450 000 tonnes d’excédent de pommes de terre en France\u202f?  https://t.co/VRnM13qeqs https://t.co/1efC70ZowN',
#   'created_at': '2020-05-07T12:05:46.000Z'},
#  {'id': '1258367419850149890',
#   'text': 'Accountability for COVID-19 Aid: Better Visibility Matters for the Quality of the Response https://t.co/HyX6fBIkPw',
#   'created_at': '2020-05-07T12:05:46.000Z'},
#  {'id': '1258367420005117952',
#   'text': "@justsane80 @AP #COVID19 WORLD RECORD\\n\\uD83C\\uDDFA\\uD83C\\uDDF8\\uD83C\\uDDFA\\uD83C\\uDDF8\\uD83C\\uDDFA\\uD83C\\uDDF8\\uD83C\\uDDFA\\uD83C\\uDDF8\\uD83C\\uDDFA\\uD83C\\uDDF8\\uD83C\\uDDFA\\uD83C\\uDDF8\\uD83C\\uDDFA\\uD83C\\uDDF8\\uD83C\\uDDFA\\uD83C\\uDDF8\\uD83C\\uDDFA\\uD83C\\uDDF8\\uD83C\\uDDFA\\uD83C\\uDDF8\\n#Trump's inaction, incompetence &amp; criminal negligence has now cost\\n75,000 #US lives\\n\\n@realDonaldTrump is a joke\\nbut #American deaths are not funny\\n#TrumpFail #GOPSShame https://t.co/t7gkvCH1qv",
#   'created_at': '2020-05-07T12:05:46.000Z'},
#  {'id': '1258367420013645825',
#   'text': "\\uD83D\\uDCE2 IDPCnet: 'Don’t judge us—help us. That’s all we’re asking.' A compelling account of the burden that #COVID19 has imposed on street-based people who use drugs in the UK. By JSRafaelism\\n\\nFt. niamhrelease - Release_drugs, wudzee0 - UKLEAP … https://t.co/hRaxC8S9cv",
#   'created_at': '2020-05-07T12:05:46.000Z'},
#  {'id': '1258367420105986049',
#   'text': '@SenadoresdelPAN @HLGatell @Tu_IMSS @zoerobledo Mejor trabajen ustedes en una estrategia de verdad para competir si quieren ser una verdadera oposición y dejen a quienes trabajan por combatir al COVID-19 hacer su trabajo. Les duele que salga la verdad de su gran amigo el Borolas.\\n\\n#YoSíCreoEnLópezGatell',
#   'created_at': '2020-05-07T12:05:46.000Z'},
#  {'id': '1258367420210831362',
#   'text': 'Meeste jongeren gedragen zich, maar ‘Het is supermoeilijk ‘nee’ te zeggen als al je vrienden nu naar een feest gaan’ aldus @HetNJi onderzoeker Nikki Udo in @DeGelderlander:\\nhttps://t.co/wunqsmHIhV #coronavirus',
#   'created_at': '2020-05-07T12:05:46.000Z'},
#  {'id': '1258367420395331584',
#   'text': '@pimientoman Creo que hay motivos\\nhttps://t.co/jbDlmb2Vfk',
#   'created_at': '2020-05-07T12:05:47.000Z'},
#  {'id': '1258367420558909441',
#   'text': 'Revealed: the secret report that gave ministers warning of care home coronavirus crisis https://t.co/mEshgcrDKm',
#   'created_at': '2020-05-07T12:05:47.000Z'},
#  {'id': '1258367420575748096',
#   'text': '@OceAlaB @benbaert @la_bibiche je n\'en sais pas plus que qui que ce soit mais si je pensais avoir eu le Covid19 je mettrais des masques chir plutôt que des FFP2, même si j\'ai le choix. Ce qui est certain c\'est que l\'HAS ne dit pas \\"l\'infection n\'est pas immunisante\\".',
#   'created_at': '2020-05-07T12:05:47.000Z'},
#  {'id': '1258367420856537088',
#   'text': 'COVID-19 attack on US worse than 9/11: Trump | Poll Strategies | Management | Digital Bharat - an Online National Media https://t.co/ehlbTd6mPQ',
#   'created_at': '2020-05-07T12:05:47.000Z'},
#  {'id': '1258367421091545089',
#   'text': 'There are even greater enemies than the coronavirus, and they will persist long after this virus runs its course. #wisdomhunters #enemies #truth #Jesus https://t.co/sHZNhROyVt',
#   'created_at': '2020-05-07T12:05:47.000Z'},
#  {'id': '1258367421318082561',
#   'text': 'Första gången Sverige kommer som notis i Eikon:\\n\\nDEATHS IN SWEDEN FROM COVID-19 REACH 3,040, UP FROM 2,941 ON WEDNESDAY - PUBLIC HEALTH AGENCY',
#   'created_at': '2020-05-07T12:05:47.000Z'},
#  {'id': '1258367421326471170',
#   'text': 'दुनिया जब #COVID19 के ख़िलाफ़ वैक्सीन ढूंढने में लगी है,तब मोदी सरकार ICMR से पूछ कर रही है कि क्या गंगाजल से इस बीमारी का इलाज कर सकते हैं?ICMR ने कहा नहीं! \\uD83D\\uDE02',
#   'created_at': '2020-05-07T12:05:47.000Z'},
#  {'id': '1258367421418737664',
#   'text': 'Coronavirus: La OMS estudia mandar una nueva misión a China para investigar el origen del virus #Coronavirus https://t.co/Zl9VIU03j9',
#   'created_at': '2020-05-07T12:05:47.000Z'},
#  {'id': '1258367421624262656',
#   'text': 'Kurz vs Sánchez: las tres semanas de exitosa desescalada de Austria, por @diegodelacruz  https://t.co/LkStBPYMZG vía @libertaddigital\\n\\n Uno de los países en el que la oposición está de acuerdo con el gobierno. Porqué será?',
#   'created_at': '2020-05-07T12:05:47.000Z'},
#  {'id': '1258367422316384256',
#   'text': 'New #COVID19/#coronavirus numbers from the Virginia Hospital and Healthcare Association.\\n\\nCurrent patients: 1613 (+19)\\nDischarged: 2825 (+91)\\nBeds Available: 4683 (-78)\\nVentilator Use: 20% (-1%)\\nNo hospitals reporting 72-hour PPE resupply issue (unchanged).\\n\\n@CBS6 https://t.co/Hnbl4k4mRw',
#   'created_at': '2020-05-07T12:05:47.000Z'},
#  {'id': '1258367423025209346',
#   'text': "@CordeliaSkyNews @skyatlantic One day around death in a NY emergency hospital with COVID-19 patients, soon after showing of her quarantine social distancing skills....! Proud of yourself @CordeliaSkyNews ? Let's hear the double standards excuses like Neil Ferguson. https://t.co/5XsNigFvpN",
#   'created_at': '2020-05-07T12:05:47.000Z'},
#  {'id': '1258367423884951552',
#   'text': 'para algunos es un virus, para otros el karma \\"Muere el expolicía \'Billy el Niño\' por coronavirus\\"  https://t.co/hCqHMAwRol',
#   'created_at': '2020-05-07T12:05:47.000Z'},
#  {'id': '1258367423914422272',
#   'text': 'Según un informe del Instituto Carlos III, los profesionales sanitarios andaluces son los más castigados por el coronavirus. En el Hospital Virgen Macarena, los profesionales exigen el cese del gerente, ex alto cargo del sistema de salud madrileño. \\nhttps://t.co/SNsPiXjnyX',
#   'created_at': '2020-05-07T12:05:47.000Z'},
#  {'id': '1258367424522584064',
#   'text': '\\uD83D\\uDEA8CORONAVIRUS\\n@albaverges , consellera de  @salutcat declarada persona no grata a #santandreudelabarca \\nhttps://t.co/bVvffTOGQU https://t.co/GFY3R3H61I',
#   'created_at': '2020-05-07T12:05:47.000Z'},
#  {'id': '1258367424593829890',
#   'text': 'I’m more than a little annoyed that it’s MY problem to figure out how and where to return a check to my deceased father. And all because their software couldn’t spot the “Decd” after Daddy’s name. Putzes. https://t.co/Hl1npRLaQN',
#   'created_at': '2020-05-07T12:05:48.000Z'},
#  {'id': '1258367424623230976',
#   'text': 'Hem ilimizdeki çalışmaları hem de Covid-19 mücadelemizi anlatacağımız canlı yayınımız başladı. Tüm hemşehrilerimizi bekliyoruz. https://t.co/BOceaQaP7B',
#   'created_at': '2020-05-07T12:05:48.000Z'},
#  {'id': '1258367424963006465',
#   'text': "Good article about the internet and how it's holding together in the wake of #covid19. Reports that AT&amp;T has seen a 20% increase in internet traffic or 71 petabytes! #internet #internettraffic #tech  https://t.co/AcKTvMwEYu",
#   'created_at': '2020-05-07T12:05:48.000Z'},
#  {'id': '1258367424987947009',
#   'text': 'There’s other muslim community in Myanmar who is not oppressed at all. Don’t you think it’s the Rohingya people that’s actually problematic?? https://t.co/j8YCHVovcz',
#   'created_at': '2020-05-07T12:05:48.000Z'},
#  {'id': '1258367425151729664',
#   'text': '@ChuckCallesto Yes I do! #StopTheMadness #COVID19 #ChinaLiedAndPeopleDied',
#   'created_at': '2020-05-07T12:05:48.000Z'},
#  {'id': '1258367425185275905',
#   'text': 'Deliberate murder in the dark. https://t.co/zWQnum7wgd',
#   'created_at': '2020-05-07T12:05:48.000Z'},
#  {'id': '1258367425222979585',
#   'text': 'Worth a read. What our friends are saying about how  \u2066@BorisJohnson\u2069, \u2066@Conservatives\u2069 \u2066@MattHancock\u2069 acted. And this the group who say crashing out in December should happen. Unbelievable. #COVID19 #covid #ppe #testing #Brexit# https://t.co/SHH2J7e2Nl',
#   'created_at': '2020-05-07T12:05:48.000Z'},
#  {'id': '1258367427043344386',
#   'text': '@BomDiaBrasil LOGO LOGO O BRASIL ALCANÇA O PRIMEIRO LUGAR E CONQUISTA O TÍTULO NESSE CAMPEONATO DE PONTOS CORRIDOS CHAMADO CORONAVIRUS 2020 , EM DEZEMBRO SABEREMOS . https://t.co/eFvdKz958R',
#   'created_at': '2020-05-07T12:05:48.000Z'},
#  {'id': '1258367427097870337',
#   'text': 'COVID-19\\nMurder hornets\\nPolar vortex\\nIdiot humans: We wanna go outside and mingle!!\\nEarth: https://t.co/0U8qxCpOuv https://t.co/lgUysKFAjj',
#   'created_at': '2020-05-07T12:05:48.000Z'},
#  {'id': '1258367427437637632',
#   'text': 'É um massacre, de todos os lados.\\n\\nMorro de medo pela minha prima. https://t.co/eBp8femXor',
#   'created_at': '2020-05-07T12:05:48.000Z'},
#  {'id': '1258367427454226433',
#   'text': 'First Gujarati Kadha and now Treatment with Ganga Water. https://t.co/cXGcFy26ZN',
#   'created_at': '2020-05-07T12:05:48.000Z'},
#  {'id': '1258367428570087425',
#   'text': 'The PRC Sub-Committee on Refugees, Returnees &amp; IDPs bureau held a vitual meeting to discuss the humanitarian challenges posed by #COVID19 pandemic &amp; the toll on forced-displaced population \\nThe Sub-Co commits to continue its work &amp; mitigate the exacerbated humanitarian situation https://t.co/5lA2V3fNbn',
#   'created_at': '2020-05-07T12:05:48.000Z'},
#  {'id': '1258367428884680705',
#   'text': 'The Design of Marketing Globe &amp; Mail is out. Read about the latest trends in web, branding &amp; marketing https://t.co/LpiZ8Fekmu Thanks to @RecruiterPm @SalesLayer @Cunningham_UK #digitalmarketing #covid19',
#   'created_at': '2020-05-07T12:05:49.000Z'},
#  {'id': '1258367428993724418',
#   'text': 'कोरोना पर AIIMS के डायरेक्टर का बड़ा बयान, इन 2 महीनों में तेजी से फैल सकती है महामारी https://t.co/M4vFRoK7kq',
#   'created_at': '2020-05-07T12:05:49.000Z'},
#  {'id': '1258367429056565249',
#   'text': 'Wtf https://t.co/Xkh3l3CPCE',
#   'created_at': '2020-05-07T12:05:49.000Z'},
#  {'id': '1258367429068984321',
#   'text': 'https://t.co/Jcltj0emOs. Somethingisn’t right. #BingLiu was researching on #COVID19 &amp; was close to a ‘significant find’. Then he is #Killed . #Chinese assassin kills himself. #Pittsburgh Secrets in the #dark . @kayjay34350 @Chellaney @Madhurendra13 @anishsingh21 @WIONews @XHNews',
#   'created_at': '2020-05-07T12:05:49.000Z'},
#  {'id': '1258367429203431426',
#   'text': 'HOY • HOY • HOY https://t.co/MMWins8WRV',
#   'created_at': '2020-05-07T12:05:49.000Z'},
#  {'id': '1258367429463457794',
#   'text': 'Malaysia round-up of Bengalis over coronavirus: Malaysia to Myanmar and the UK legacy https://t.co/qQvRAbdOS8',
#   'created_at': '2020-05-07T12:05:49.000Z'},
#  {'id': '1258367429681561600',
#   'text': 'Worth remembering the powers conferred to the Scottish Parliament by the Coronavirus Act 2020 can be whipped off Nicola Sturgeon just as easily as they were given, if she wants to start any snash.',
#   'created_at': '2020-05-07T12:05:49.000Z'},
#  {'id': '1258367431711641600',
#   'text': 'Don’t miss this session tomorrow. https://t.co/E8uq6XXdxk',
#   'created_at': '2020-05-07T12:05:49.000Z'},
#  {'id': '1258367431841443842',
#   'text': "\\uD83D\\uDC81\u200d♀️ Ali Fazal and Richa Chadha's marriage postponed in lockdown, know what you should do in such circumstances \\uD83D\\uDC47\\nVisit \\uD83D\\uDC49 https://t.co/5BBjxlTFx6\\n#lockdownindia #lockdwn #COVID__19\\n#coronavirus #Pulwama #boislockeroom\\n#MODIJI_HelpUs #RiyazNaikoo #WhyMillionsEatVeg https://t.co/S9eQ7CNcRS",
#   'created_at': '2020-05-07T12:05:49.000Z'},
#  {'id': '1258367431900139522',
#   'text': 'News Kejriwal 3.0 Govt,\\n\\nदिल्ली पुलिस के कॉंस्टेबल आमित की मृत्यु Covid-19 से हुई,\\n\\nकेजरीवाल सरकार अमित जी के परिवार को ₹1 सहायता राशी देगी।\\n\\nThx. @ArvindKejriwal ji',
#   'created_at': '2020-05-07T12:05:49.000Z'},
#  {'id': '1258367432500088832',
#   'text': 'El ejército de EE.UU. usa tecnología térmica para combatir la\xa0COVID-19 https://t.co/rFUE5xm10z',
#   'created_at': '2020-05-07T12:05:49.000Z'},
#  {'id': '1258367432567242752',
#   'text': 'Some non-#COVID19 news. A newly discovered #BlackHole! New fact for me is that astronomers have long assumed the Milky Way, our unimportant galaxy, may have hundreds of millions of black holes. One of them is living in the White House. https://t.co/FzELgejLnL',
#   'created_at': '2020-05-07T12:05:49.000Z'},
#  {'id': '1258367432856567808',
#   'text': 'Shri Rahul Gandhi in conversation with Dr. Raghuram Rajan on COVID19 &amp; i... https://t.co/fLKwczA2fD via @YouTube',
#   'created_at': '2020-05-07T12:05:49.000Z'},
#  {'id': '1258367433028636677',
#   'text': 'Cannabis CBD shows promise blocking coronavirus infection: Alberta researcher https://t.co/9StY9blzc0',
#   'created_at': '2020-05-07T12:05:50.000Z'},
#  {'id': '1258367433322237952',
#   'text': 'BREAKING: Notting Hill Carnival cancelled this year due to coronavirus - official statement released today\\n\\nhttps://t.co/8gv7N1uxt5',
#   'created_at': '2020-05-07T12:05:50.000Z'}]

# %% [markdown]
# Below we implement a check to make sure we are on the right track. This simple function and assert statement are there to alert us if we extract fewer than <b>1172</b> tweets ( which are the total number tweets in the sample data). Python's ```eval``` function was used to find the total number of tweets. Although ```eval``` is unreliable most times when dealing with text data, it works for this purpose to just get the number of tweets in the sample.

# %%
tweet_data_sam = []
for text in sample_data:
    data_pattern = r"\[\{.*\:.*\}\]\,"
    matches = re.search(data_pattern, text)
    _data = matches.group()[:-1]
    _data = eval(_data)
    tweet_data_sam.append(_data)

lens = []
for text in tweet_data_sam:
    lens.append(len(text))

print(f"There are {sum(lens)} tweets in the sample data")
# Out:
# There are 1172 tweets in the sample data

# %%
def sanity_check(list_of_dicts):
    """Function returns a list of texts containing all the tweet texts in the text

    Args:
        tweet_file (str, mandatory) : a tweet string from which text need to be extracted.

    Returns:
        list : List of texts in a tweet text"""    
    
    lengths = []
    i = 0
    for element in list_of_dicts:
        lengths.append(len(element))
    return sum(lengths)

assert sanity_check(tweets_sample) == 1172, "Total number of tweets not matching! \
                                            there should 1172 tweets! "

# %% [markdown]
# ## 5. Create a date dictionary
# In this next step we create a nested dictionary which has the unique dates in the dataset as the keys while in the dictionary, the ```id``` of the tweet is the key and ```text``` of the tweet is the value of the dictionary. In order to create this, the function  initialises an empty dictionary. We iterate through each list element looking for unique date matches which become the key of this new dictionary.
#
# <br>
# <center><b><font size=5, color="blue"> Text Preprocessing </font></b></center>
# <br>
#
# Before we add the text to inner dictionary as the value, we need to preprocess it inorder to match the output of the sample file. Here is the list of preprocessing performed :
#
# * Surrogate pairs
# In order to refer the characters outside of the initial [BMP](https://en.wikipedia.org/wiki/Plane_(Unicode)#Basic_Multilingual_Plane), Universal Character Sets(UCS) use a pair containing a high surrogate (D800–DBFF) and a low surrogate(DC00–DFFF). Examples of these characters appearing in our text are \\uDDF2, \\uD83C, \\uDDEB etc. These are emoji encodings and these characters mislead the classifier and give us the wrong sample output. In order to avoid this, a regex is designed to capture these surrogate pairs.
#
#
# * ```r'\\*uD[8A-F][A-F0-9]{2}'```
# This regex captures anything that starts with a ```\uD``` followed by either 8 or an alphabet between A and F then followed by two characters which could be between A-F and 0-9. This logic is implemented using character classes and note the use of ```{}``` to indicate exactly two characters.
#
#
# * We then go on to replace quotation marks, apostrophes, less than, greater than with  XML's predefined entities (note that we don't replace ampersand because it is automatically being encoded while writing the file). We also replace the ```\\n``` with ```\n``` to match the sample output and enable formatting in our XML output
#
#
# * Following this, encoding is done to allow surrogate pairs and the text is then classified. The text is now finally added to our dictionary.

# %%
def get_date_dict(tweets):
    """Function returns a list of texts containing all the tweet texts in the text

    Args:
        tweet_file (str, mandatory) : a tweet string from which text need to be extracted.

    Returns:
        list : List of texts in a tweet text"""
    
    classified_tweets = {}

    for list_elm in tweets:
        for tweet in list_elm:
            date_pattern = r'([12]\d{3}-(0[1-9]|1[0-2])-(0[1-9]|[12]\d|3[01]))'
            date = re.search(date_pattern, tweet['created_at']).group()

            if date not in classified_tweets:
                classified_tweets[date] = {}

            tweet_text = tweet['text']
            tweet_id = tweet['id']

            # Replace troublesome characters 
            tweet_text = re.sub(r'\\*uD[8A-F][A-F0-9]{2}', \
                              lambda x:eval('"' + x.group() + '"'), tweet_text)
            tweet_text = re.sub(r'\\"', "&quot;", tweet_text)
            tweet_text = re.sub(r"\'", "&apos;", tweet_text)
            tweet_text = re.sub(r"<", "&lt;", tweet_text)
            tweet_text = re.sub(r">", "&gt;", tweet_text)
            tweet_text = re.sub(r'\\n', '\n', tweet_text)

            # enable surrogate pass
            tweet_text = tweet_text.encode('utf-16', 'surrogatepass').decode('utf-16')

            # This functions language code and probability score in a tuple
            # Classify the text using the function
            language, prob = classify(tweet_text)

            if language == 'en':
                classified_tweets[date][tweet_id] = tweet_text

    return classified_tweets

english_tweets_sample = get_date_dict(tweets_sample)

# %%
english_tweets_sample
# Out:
# {'2020-05-07': {'1258367403953500164': '@thehill Trump’s Ridiculous Behavior about Covid19 at Pandemic Briefings Battles https://t.co/4Gjy5tQ4XI https://t.co/8vcxU75Nz4',
#   '1258367405157466112': '‘Complacent’ UK draws global criticism for Covid-19 response https://t.co/Qmd2GSQPY5',
#   '1258367406285762560': '@Eglisecatho @Diocese72 +55 (22)981565421\nDon&apos;t you have a BRAIN?\nOnly (martial law)HOME PRISON, during 30 days, of all(100%) CITIZENS will stop CORONA VIRUS.\nNo more deaths.\nThe economy will be normal in 30 days too.\n CURE See Dra Eunara Negri discovered the CURE of CORONAVIRUS.\nhttps://t.co/2uLsT6Eehn',
#   '1258367407606960129': 'UK contact-tracing app could fall foul of privacy law, government told\n\nhttps://t.co/W85NfMKadm',
#   '1258367407653040133': 'Do you want to be up to date with #coronavirus worldwide? It is a good idea to attach this 👇 page to your sources. https://t.co/1mh5p6IQFz',
#   '1258367407770472449': '2 Utah County businesses told staff to ignore COVID-19 guidelines, resulting in 68 positive cases | Local News | https://t.co/XhYEBoqOfJ https://t.co/q33WGNwikg',
#   '1258367408252817410': 'Are 2 mahine me kitni baar fake news doge https://t.co/esxocgOQ1D',
#   '1258367408504528896': '@girlsreallyrule @joncoopertweets Speaking of investigations about bungled responses to the pandemic, there needs to be an investigation into the Trump Administration’s atrocious mismanagement of COVID19 in the USA.',
#   '1258367408508743680': 'Listen to this man all the way to the end. https://t.co/ttDtR278nG',
#   '1258367408689033217': '@CortesSteve Cook Country #Democrats, especially @chicagosmayor &amp; @ToniPreckwinkle, will &quot;goose&quot; step w/@GovPritzker, but - MANY counties around #Illinois that aren&apos;t so in bed with #Dems, where #Covid19/#CoronaVirus isn&apos;t so prevalent, should revolt &amp; start to #reopenillinois, safely. #twill',
#   '1258367408923914241': '@realDonaldTrump, @WhiteHouse Why can’t we see the #CDC #COVID19 recommendations? What are you hiding? https://t.co/SVeFHfsHmW',
#   '1258367409292894208': '#KASARAGOD \n#KERALAHEALTHDEPARTMENT https://t.co/aKt7C9RQpz',
#   '1258367410568036352': '@HillaryClinton How is trump “winding down” when people are still dying and we’re still quarantined? There’s still no immunization against this flu. Coronavirus isn’t taken as serious as it should. This is the first pandemic of the digital age and it’s not over!',
#   '1258367410781876224': 'As we bail out highly leveraged corporations and oil which was heading south prior to virus https://t.co/0onTRbY5Mn',
#   '1258367412543590400': '@10DowningStreet please take note! https://t.co/Gb7tT4hqfn',
#   '1258367412778524672': 'Jaime Bofill highlights financial measures by #Spain &amp; #eu to shield companies from economic effects of #covid19 #financialinstitutions #financialregulation https://t.co/fVKUkCynmC',
#   '1258367412786864131': 'New study reveals most Europeans support basic income after COVID-19 | University of Oxford https://t.co/kLywpLSS5o',
#   '1258367412799508480': 'I don’t trust the UN so maybe Assange should be moved to the US? 🤔 https://t.co/AUDL3P2jfT',
#   '1258367412891770880': '@cjohansen_MT @goldiett7 @R_ZenBo But didn’t you worry about the servers of the food and how that could be unwittingly spreading covid19? We are avoiding dining in restaurants.',
#   '1258367412904382464': 'Apple Awards $10 Million to COVID-19 Testing Kit Maker From Advanced Manufacturing Fund. I Hate Everything.',
#   '1258367413524918273': 'So great to see @clubmaseratixxx in the latest update from @Brazzers and that too with @MarkusDupree ! Hope to see more of @BbwSofiaRose @MillyMarksxxx and @spitneyspears too ! #ThursdayThoughts #NursesDay2020 #BBW #COVID19 #Faptastic ! https://t.co/RIvpdHv2Kj',
#   '1258367414590472195': 'This is a great step in the right direction. Can we also stop the private sale of non #COVID19 test kids and the public sale of all test kids?!?! In fact, stop the sale of all kids, public or private!!! #kidsarepeopletoo #wellsorta #oknotreally #butalmost https://t.co/P2Si5ufZOf',
#   '1258367415080988672': '@CNN UK has reported more than 30,000 deaths, highest in Europe\n\nLatest updates | # cases per million population👇\n\nhttps://t.co/TqfSuFkkLd\n#COVID19 #Covid_19',
#   '1258367415559368710': 'Due to #COVID19 aka #Coronavirus Ill be sending the first 350 people that like &amp; retweet this up to $3000 through cashapp, apple pay, paypal or zelle (Must DM ME cashapp name or phone number first) https://t.co/PXLwZuNHRe',
#   '1258367415672606720': '@BettGunther Your pretty picture does NOT accurately reflect WHO advice...you know that but it doesn&apos;t fit your story...  https://t.co/aTHxfMCcZG',
#   '1258367415806832640': 'Outsourcing the coronavirus crisis to business has failed – and NHS staff know it https://t.co/QOEJWb49Eu',
#   '1258367416830234625': 'BBC News - &quot;Men with advanced prostate #cancer can take highly targeted hormone therapies at home instead of coming into hospital for chemotherapy, @NHSEngland says&quot; - https://t.co/XYTzZIlOTP\n@ProstateUK @NewbCancerCare @macmillancancer @HealthwatchE @PHE_uk @KennetRadio #covid19',
#   '1258367419090944000': 'When you’re bored and @starboyterri  -#OJORO  comes up #coronavirusghana #level3 #lockdownextension #istandwithbuhari #COVID19 https://t.co/F1mGMAj8Ao',
#   '1258367419170488320': '@Breaking911 Kalifornistan wants America to backfill its Corona deficit. Be cautious, everyone who passes will become a virus death, any red ledger problems will be due to Covid19.',
#   '1258367419233570816': 'Trump’s New Coronavirus Message: Time to Move On to the Economic Recovery https://t.co/9cU0UIjt9N',
#   '1258367419497828353': 'BOMBSHELL! CBS News Caught Staging &quot;Fake Patient&quot; in COVID-19 Testing https://t.co/UrwXyeHc7O',
#   '1258367419850149890': 'Accountability for COVID-19 Aid: Better Visibility Matters for the Quality of the Response https://t.co/HyX6fBIkPw',
#   '1258367420013645825': '📢 IDPCnet: &apos;Don’t judge us—help us. That’s all we’re asking.&apos; A compelling account of the burden that #COVID19 has imposed on street-based people who use drugs in the UK. By JSRafaelism\n\nFt. niamhrelease - Release_drugs, wudzee0 - UKLEAP … https://t.co/hRaxC8S9cv',
#   '1258367420558909441': 'Revealed: the secret report that gave ministers warning of care home coronavirus crisis https://t.co/mEshgcrDKm',
#   '1258367420856537088': 'COVID-19 attack on US worse than 9/11: Trump | Poll Strategies | Management | Digital Bharat - an Online National Media https://t.co/ehlbTd6mPQ',
#   '1258367421091545089': 'There are even greater enemies than the coronavirus, and they will persist long after this virus runs its course. #wisdomhunters #enemies #truth #Jesus https://t.co/sHZNhROyVt',
#   '1258367422316384256': 'New #COVID19/#coronavirus numbers from the Virginia Hospital and Healthcare Association.\n\nCurrent patients: 1613 (+19)\nDischarged: 2825 (+91)\nBeds Available: 4683 (-78)\nVentilator Use: 20% (-1%)\nNo hospitals reporting 72-hour PPE resupply issue (unchanged).\n\n@CBS6 https://t.co/Hnbl4k4mRw',
#   '1258367423025209346': '@CordeliaSkyNews @skyatlantic One day around death in a NY emergency hospital with COVID-19 patients, soon after showing of her quarantine social distancing skills....! Proud of yourself @CordeliaSkyNews ? Let&apos;s hear the double standards excuses like Neil Ferguson. https://t.co/5XsNigFvpN',
#   '1258367424593829890': 'I’m more than a little annoyed that it’s MY problem to figure out how and where to return a check to my deceased father. And all because their software couldn’t spot the “Decd” after Daddy’s name. Putzes. https://t.co/Hl1npRLaQN',
#   '1258367424963006465': 'Good article about the internet and how it&apos;s holding together in the wake of #covid19. Reports that AT&amp;T has seen a 20% increase in internet traffic or 71 petabytes! #internet #internettraffic #tech  https://t.co/AcKTvMwEYu',
#   '1258367424987947009': 'There’s other muslim community in Myanmar who is not oppressed at all. Don’t you think it’s the Rohingya people that’s actually problematic?? https://t.co/j8YCHVovcz',
#   '1258367425151729664': '@ChuckCallesto Yes I do! #StopTheMadness #COVID19 #ChinaLiedAndPeopleDied',
#   '1258367425185275905': 'Deliberate murder in the dark. https://t.co/zWQnum7wgd',
#   '1258367425222979585': 'Worth a read. What our friends are saying about how  \u2066@BorisJohnson\u2069, \u2066@Conservatives\u2069 \u2066@MattHancock\u2069 acted. And this the group who say crashing out in December should happen. Unbelievable. #COVID19 #covid #ppe #testing #Brexit# https://t.co/SHH2J7e2Nl',
#   '1258367427097870337': 'COVID-19\nMurder hornets\nPolar vortex\nIdiot humans: We wanna go outside and mingle!!\nEarth: https://t.co/0U8qxCpOuv https://t.co/lgUysKFAjj',
#   '1258367427454226433': 'First Gujarati Kadha and now Treatment with Ganga Water. https://t.co/cXGcFy26ZN',
#   '1258367428570087425': 'The PRC Sub-Committee on Refugees, Returnees &amp; IDPs bureau held a vitual meeting to discuss the humanitarian challenges posed by #COVID19 pandemic &amp; the toll on forced-displaced population \nThe Sub-Co commits to continue its work &amp; mitigate the exacerbated humanitarian situation https://t.co/5lA2V3fNbn',
#   '1258367428884680705': 'The Design of Marketing Globe &amp; Mail is out. Read about the latest trends in web, branding &amp; marketing https://t.co/LpiZ8Fekmu Thanks to @RecruiterPm @SalesLayer @Cunningham_UK #digitalmarketing #covid19',
#   '1258367429056565249': 'Wtf https://t.co/Xkh3l3CPCE',
#   '1258367429068984321': 'https://t.co/Jcltj0emOs. Somethingisn’t right. #BingLiu was researching on #COVID19 &amp; was close to a ‘significant find’. Then he is #Killed . #Chinese assassin kills himself. #Pittsburgh Secrets in the #dark . @kayjay34350 @Chellaney @Madhurendra13 @anishsingh21 @WIONews @XHNews',
#   '1258367429463457794': 'Malaysia round-up of Bengalis over coronavirus: Malaysia to Myanmar and the UK legacy https://t.co/qQvRAbdOS8',
#   '1258367429681561600': 'Worth remembering the powers conferred to the Scottish Parliament by the Coronavirus Act 2020 can be whipped off Nicola Sturgeon just as easily as they were given, if she wants to start any snash.',
#   '1258367431711641600': 'Don’t miss this session tomorrow. https://t.co/E8uq6XXdxk',
#   '1258367431841443842': '💁\u200d♀️ Ali Fazal and Richa Chadha&apos;s marriage postponed in lockdown, know what you should do in such circumstances 👇\nVisit 👉 https://t.co/5BBjxlTFx6\n#lockdownindia #lockdwn #COVID__19\n#coronavirus #Pulwama #boislockeroom\n#MODIJI_HelpUs #RiyazNaikoo #WhyMillionsEatVeg https://t.co/S9eQ7CNcRS',
#   '1258367432567242752': 'Some non-#COVID19 news. A newly discovered #BlackHole! New fact for me is that astronomers have long assumed the Milky Way, our unimportant galaxy, may have hundreds of millions of black holes. One of them is living in the White House. https://t.co/FzELgejLnL',
#   '1258367432856567808': 'Shri Rahul Gandhi in conversation with Dr. Raghuram Rajan on COVID19 &amp; i... https://t.co/fLKwczA2fD via @YouTube',
#   '1258367433028636677': 'Cannabis CBD shows promise blocking coronavirus infection: Alberta researcher https://t.co/9StY9blzc0',
#   '1258367433322237952': 'BREAKING: Notting Hill Carnival cancelled this year due to coronavirus - official statement released today\n\nhttps://t.co/8gv7N1uxt5',
#   '1258367433590681601': 'Fabulous #edityourlifeshow interview with @lashawnwiltz. This ep was recorded pre-pandemic shut down so COVID-19 does not factor into the conversation but the topic is relevant for right now as everyday moments are what we have to lean into in abundance.  https://t.co/jOHnTgbvv5',
#   '1258367433636806656': '“It has called for new legislation with guaranteed data and human rights protections, as well as an independent body to oversee the use, effectiveness and privacy protections of the app and any data associated with this contact-tracing,” https://t.co/DxJUxQaaHz',
#   '1258367436258238464': 'Kano commissioner sacked for ‘celebrating Abba Kyari’s death’ contracts coronavirus - TODAY https://t.co/92YCOOTBws via @todayng',
#   '1258367436618977280': 'Economists, and Chinese government officials, are generally pessimistic about China’s ability to sustain the April export strength, particularly as the growth picture sours further in the U.S. and Europe. \n\nhttps://t.co/66aAjIZJgG',
#   '1258367439974174720': 'Electoral votes is what counts! President Trump won 304-227 in 2016! Trump-Pence 2020 and beyond by another landslide! President Trump and his administration is the best that we have had since Reagan and before that Lincoln! https://t.co/IbwgQGuUSg',
#   '1258367440100241410': 'Of course we knew it but now confirmed 😡 https://t.co/Nm4qwBrLhO',
#   '1258367440708304896': 'The pandemic will change urban life forever. We asked 12 leading global experts in urban planning, policy, history, and health for their predictions. https://t.co/7B2ieOgQuM',
#   '1258367440758747137': 'Unsanitized: We Are Moving Confidently and Proudly Into Mass Death - The American Prospect \u2066@CarlosAlvQ\u2069 \u2066@msaludcr\u2069 \u2066@MiamiMayor\u2069  https://t.co/cjWmRukmt5',
#   '1258367440855187456': '@Diocese72 @RCFSarthe @Pontifex_fr @bleumaine @lemainelibre @F3PaysdelaLoire @OuestFrance72 @SweetFmRadio @Eglisecatho @fbarille @JuLeDuff @LaureGirard @Lespiegle1 @Thierry_Fourmy @abbegaetan +55 (22)981565421\nDon&apos;t you have a BRAIN?\nOnly (martial law)HOME PRISON, during 30 days, of all(100%) CITIZENS will stop CORONA VIRUS.\nNo more deaths.\nThe economy will be normal in 30 days too.\n CURE See Dra Eunara Negri discovered the CURE of CORONAVIRUS.\nhttps://t.co/2uLsT6Eehn',
#   '1258367441249415168': '15,000 SMEs have been affected due to the curfew set in place the COVID-19 Pandemic #KEPSALive',
#   '1258367441438007296': 'Magic Leap’s possible death throes have little to do with COVID-19 https://t.co/RiW5FVAU3S',
#   '1258367441530286081': 'Handling Covid19 has made me realise:\n(a) Our offices may be clean but not sanitised. \n(b) Just because they were cleaned &amp; closed doesn&apos;t mean there hasn&apos;t been toxic built up. \n(c) This isn&apos;t your normal &quot;mop &amp; sweep&quot; situation. \nIt requires experts, acknowledge and reach out.',
#   '1258367442432036865': 'Over 9000 pregnant women on list of Keralites ready to return https://t.co/f3mpFyg15d',
#   '1258367443858329600': 'Five Software Programs to Use During COVID-19 Berbay Marketing &amp; PR Los Angeles CA https://t.co/L5cQlyIuxY https://t.co/yJxeD4B7gy',
#   '1258367444332281856': '@bbellgam @Oddy4real An economic depression will kill more people than a war?Only yesterday, covid19 mortality deaths in the US surpassed US fatality numbers in Vietnam war. You are exaggerating the impact of an economic downturn.Nothing trumps human life-again,to people whose souls are still intact.',
#   '1258367444529434624': 'Veterinary Lasers Market Revenue to Decline During Coronavirus Disruption, Stakeholders to Realign Their Growth Strategies\nhttps://t.co/SCtoFLwVOs\n#news #pharma #pharmiweb',
#   '1258367444785065990': 'All going to die if we don&apos;t fix our Climate problem...\ngoing to make #COVID19 look like a walk in the park..\n\nFunnily enough.. we&apos;re fucking good at not walking in the park when it means people will die....\n\nso we can adapt to #ClimateChange  with pain but life is worth it',
#   '1258367445510864897': 'Cases day by day are surging and he is lifting lockdown https://t.co/HDLzB40xKU',
#   '1258367446081101825': '@nayantaran @ameyann @sayakd @zoom_us @AshokaUniv @MenonBioPhysics @livemint @sh_devulapalli .@MenonBioPhysics- Most of the models are about moving peoplefrom one box to another. He talks of models that hypothetically move people between 3 boxes to models that use 9 boxes. These approaches are used to make #COVID19 models. #PROTOcall',
#   '1258367447813558273': 'communist china lied and covered up their covid19 outbreak last year 2019.\n\nThe result, a virus pandemic that started in communist china, by chinese people \n#FirstThem @FirstThemNEWS #BlackFirst #chinese #BlackNews @WayneDupreeShow https://t.co/PV53x7JRHS',
#   '1258367448136515585': 'Daily electricity demand impacts from COVID-19 mitigation efforts differ by region https://t.co/iN9AH7iAiD @EIAgov #economy #tech #energy #FridaysForFuture #Fridays4Future #FridayForFuture',
#   '1258367448191053824': 'On 8 May, EMERGENCY will join &apos;CTSNet Live from Africa: Perspectives on COVID-19 from Sub-Saharan Cardiac Centres&apos;. Our cardiac surgeons Dr Salvati and Dr Puntila will share the Salam Centre&apos;s approach to responding to #COVID19. Join the webinar here: https://t.co/ufDKXdwOAG https://t.co/2HBRB0ideZ',
#   '1258367448291606530': 'Daily electricity demand impacts from COVID-19 mitigation efforts differ by region https://t.co/ySEMXOyGGU',
#   '1258367448383922176': 'Daily electricity demand impacts from COVID-19 mitigation efforts differ by region #Energy https://t.co/jqt6kyI9SK',
#   '1258367448400695297': 'Daily electricity demand impacts from COVID-19 mitigation efforts differ by region https://t.co/mDcMK9jwAw',
#   '1258367448421711874': 'Was anyone actually able to reschedule? This is a disaster #MCAT #AAMC @AAMC_MCAT https://t.co/q9YWAeugjQ',
#   '1258367448522391554': 'Daily electricity demand impacts from COVID-19 mitigation efforts differ by region https://t.co/sgGQzWphua',
#   '1258367448564346883': 'Daily electricity demand impacts from COVID-19 mitigation efforts differ by region https://t.co/tJJP14eO6V',
#   '1258367448639844353': 'Daily electricity demand impacts from COVID-19 mitigation efforts differ by region https://t.co/7L2Yu4CkXK',
#   '1258367448828522497': 'Cellulite Treatment Market to Face a Significant Slowdown in 2029, as COVID-19 Sets a Negative Tone for Investors\nhttps://t.co/fuMWbaOAQN\n#news #pharma #pharmiweb',
#   '1258367448828596224': 'Daily electricity demand impacts from COVID-19 mitigation efforts differ by region https://t.co/i6BlSlWiHr',
#   '1258367448916660224': 'Daily electricity demand impacts from COVID-19 mitigation efforts differ by region https://t.co/lze9GIivZz',
#   '1258367448975360002': '82 New Coronavirus Infections Recorded In Lagos https://t.co/tAbm77VWD1 via @silverbirdtv',
#   '1258367448996290561': 'Oh so what happens if there isn’t one https://t.co/ym1G6o5v4D',
#   '1258367449013071873': '.@NicolaSturgeon answering a &quot;rent a view&quot; question says quite pointedly: &quot;There are people out there with varying degrees of expertise on the specific situation we&apos;re facing.&quot;\n#Covid19',
#   '1258367449097011205': 'Daily electricity demand impacts from COVID-19 mitigation efforts differ by region https://t.co/bDdZeZM56K',
#   '1258367449235423237': 'Retail Advertising During Covid-19 via @Sprinklr&apos;s blog https://t.co/NYIqf9mDwy https://t.co/qQOUjIK4F0',
#   '1258367449268989954': '&quot;...the modern economy is built on a sort of just-in-time financial supply chain, in which the solvency of businesses and households depends on the prompt arrival of a vast number of debt-service payments from other businesses and households.&quot; https://t.co/IdlBGves5l',
#   '1258367449344487432': 'Daily electricity demand impacts from COVID-19 mitigation efforts differ by region https://t.co/7WWqXaGLgH',
#   '1258367449386356736': 'Daily electricity demand impacts from COVID-19 mitigation efforts differ by region https://t.co/mwmLivw08f',
#   '1258367449436733440': 'Daily electricity demand impacts from COVID-19 mitigation efforts differ by region https://t.co/B667vlcVS5',
#   '1258367449709379584': 'Yep. https://t.co/EQsc84GtPt',
#   '1258367450351120385': 'Daily electricity demand impacts from COVID-19 mitigation efforts differ by region https://t.co/RAwWtsBVTs',
#   '1258367452473364481': 'Catch up on the latest news from #AKHAN Semiconductor, including what we&apos;re doing to aid in the fight against #COVID19   https://t.co/5GdzHFyfjE https://t.co/x5gjAAfiPf',
#   '1258367453077233670': 'WTH https://t.co/zVciHoBjqi',
#   '1258367453115166721': 'Leaders need to be tough on action but gentle on approach when dealing with their employees during crisis times such as the COVID-19 pandemic.\n@SBSAlumniKE \n#sbswebinarseries #navigatingthepandemic #StayAtHome #keepsafe #keeplearning',
#   '1258367453119369216': 'Here are the 10 states where COVID-19 dropped the fastest last week — and the 10 states that saw the biggest increases https://t.co/pVyl9HgxTM',
#   '1258367453165424641': 'Don&apos;t expect a snapback for the UK economy after lockdown is lifted https://t.co/3VcMgvisg6',
#   '1258367453203238914': 'Madness - this is a massive problem. https://t.co/pjVjrHsKKI',
#   '1258367453396156416': 'Jabulani police station closes detective unit after officer tests positive for\xa0Covid-19 https://t.co/fqPUSZdZtC',
#   '1258367453924655105': '@PattyAngel64 @gooner1jdc @realDonaldTrump Predictions for COVID19 were wildly exaggerated! The math didnt add up from what we heard from W.H.O Experts and DNC, MSM (ABC NBC CNN CBS MSNBC NYTimes)! What Happened Here People?#FoxAndFriends #Hannity #IngrahamAngle #MZHemingway @LevinTV #Hannity #Trump2020 #TuckerCarlson',
#   '1258367454004350976': 'WTAF? https://t.co/RxN4V7aog8',
#   '1258367454117584896': 'the source really said dead ass? lmaooooo https://t.co/3xneryP4oZ',
#   '1258367454323097600': 'A must self knowledge about #coronavirus #COVID19 Asymptomatic patients with hardly any obvious signs should figure it out themselves. https://t.co/hwlMj7q6oG',
#   '1258367454423572480': 'Bitch where https://t.co/CbAnUvZB6R',
#   '1258367456097099776': '#NoidaCOVID19 Updates\n\nToday 10 new #COVID19 Covid-19 cases in Gautam Buddh Nagar\n\nTotal Cases - 202\nCured -  109\nActive  - 93 https://t.co/DEoxXXubeZ',
#   '1258367456550232065': '@emzanotti @MeghanMcCain Well, I think we thought we were buying time for scientists to come up with a viable treatment. As far as I understand, they’re still figuring Covid-19 out.',
#   '1258367456734785537': '@MollyJongFast &quot;... for the first time in 150 years, the world is facing a global crisis and people are not looking towards the US for global leadership, they are looking to Merkel,&quot; said Andrea Römmele, a professor at the Hertie School...&quot; https://t.co/bxVwQOkvOG',
#   '1258367457384902656': '@real_mercyeke Those that suppose travel out from Nigeria to Indonesia but because of this pandemic virus covid19 they couldn&apos;t before their visa expired during this lockdown what will be their fate on this visa after the lockdown?',
#   '1258367457884090368': '@CheetahPlains The second wave might be detrimental \n\nhttps://t.co/knDHGlVUDx',
#   '1258367457934413825': 'Anti-Vaxxer fakes, frauds, and scammers are pumping out obscene amounts of propaganda onto social media. #COVID19',
#   '1258367458655612929': 'Five Eyes network contradicts theory #Covid19 leaked from lab. \n#TrumpLiesAmericansDie  https://t.co/bXxrLPlxVL',
#   '1258367458676822016': 'The cdc should be sharing opinions with the feds who combines all necessary precautions and info to us nationwide publicly #COVID19',
#   '1258367458785865728': 'https://t.co/X80telIdCo',
#   '1258367459104641026': '3 McDonald&apos;s workers hurt after customer attack over coronavirus limits, Oklahoma police say\n\n#WhatsWrongWithPeople \n\nhttps://t.co/pylpxnZVFV',
#   '1258367460052516864': 'Good for u @IMFNews thanks for your support to Kenyan and Uganda people, what about us in Tanzania are you planning to support us? https://t.co/2K2StYSMa7',
#   '1258367460748791808': 'These numbers are almost certainly low due to lack of testing.  The toll COVID is taking in the US is unfathomable https://t.co/EJNBuvfVrf',
#   '1258367461939953664': 'Nope--typical Trump https://t.co/GMd0wtIgro',
#   '1258367462032191489': 'Hell yeah! https://t.co/TMHqjEAVel',
#   '1258367462099357696': 'Australian Prime Minister @ScottMorrisonMP and Israeli Prime Minister @netanyahu together on a call, along with 6 other world leaders, representatives of their countries who have done better than any other in stopping the spread of #COVID19. https://t.co/iQDaFfnk0N',
#   '1258367377634242561': 'Disiplina. https://t.co/hPXQP8hg8O',
#   '1258367378141917185': 'Today we examined the state of the fight with #climatechange in the context of #covid19. To learn more about this issue, #signup to Polis Analysis: https://t.co/YjfalyLCuq\n\n#emissions #environment #pollution #eu #startups https://t.co/RQ57cC6VH7',
#   '1258367378246660096': 'Sundance Film Festival Possible Site Of Early COVID-19 Outbreak https://t.co/ta9NRkNJs4',
#   '1258367378519396354': 'New post (Chicago butcher shops running low on meat amid coronavirus pandemic) has been published on BuzzyBuzz - https://t.co/QPcTR1nC34 https://t.co/eFwsvmF7pG',
#   '1258367378922123265': 'Australia hits back at US claim linking coronavirus to Wuhan lab https://t.co/qeX9KCdynw',
#   '1258367379056312320': 'Coronavirus Task Force Will Remain, Says Trump, Because It’s ‘Popular’ https://t.co/Y5DgwfVRSR',
#   '1258367379731632129': 'GARBAGE TAKE: NBC News claims Trump is surrendering to the coronavirus [ALSO: Trump says coronavirus task force to continue on…] – The Right Scoop \u2066@chucktodd\u2069 with his mouth open Looks more like a Fly catcher than a newsman !!!👹 https://t.co/7MyCJ4hfG1',
#   '1258367380985700353': '@KFC_UKI got some free advertising here! https://t.co/376nYLFR7j',
#   '1258367381786722311': 'Cases in the U.S. | CDC https://t.co/uymeptOcTV',
#   '1258367381987930112': 'Every business is now software driven! \nChange is the only constant\n#CXO Symposium organized by #HRIA\n\n#Webinar | 7th May 2020 | 4.00 PM to 5.30 PM\n#Learning in #COVID19 #Lockdown\n\n@HRInfotech',
#   '1258367382021685250': 'I wish him quick recovery.\nGet well Soon.\nMay the Almighty forgive you. https://t.co/e2Ee0WpFCw',
#   '1258367382399131656': 'Court Assistant David Lloyd-Owen, MD of Envisager, has written a fascinating report “How sewage is helping us to understand the dynamics of Covid-19 infections”. This key report has been widely distributed to the media and technical groups. Full details on our website shortly. https://t.co/BhGNH8VLU7',
#   '1258367382961127424': 'PakistanNet is out! https://t.co/XXnUU8Ikk2 Stories via @UNDP_Pakistan #undpinpakistan #covid19',
#   '1258367383170932736': '@NYGovCuomo and thanks to you and the shithole known as NY &amp; NYC, the rest of the country has suffered: &quot;New York City’s coronavirus outbreak grew so large by early March that the city became the primary source of new infections in the United States&quot; https://t.co/K05d5K3GPW',
#   '1258367385158983681': '@Thomas1774Paine This is old news, rehashed: https://t.co/MkPxnzeP3J\n\n2 strains.\n1. Lethal L strain, originally bulk of cases. China, Iran, Italy.\n2. Safer S strain, more contagious and immunizes you to BOTH strains.\n\nS is the &quot;off switch&quot; for L.\n\nBioweapon.\n\nThe viral equivalent of a flashbang.',
#   '1258367385909760001': '@SingleWindowUG is facilitating safe international trade of essential commodities during the COVID-19 period. @TradeMarkEastA @UNDAuthority @UNBSug @URAuganda https://t.co/ponEMMShlx',
#   '1258367386056523780': 'Seriously punchy from the EU&apos;s trade commissioner \nhttps://t.co/zucTW1zejP',
#   '1258367386748702723': 'With a work hat on, we’re all trying to make sense of the continually emerging picture on Coronavirus and the impacts on social trends. If there are any disability specific sources of information, then please let me know:)',
#   '1258367387105189888': '@Blueber13415354 @Hedd_Wyn_John @afneil Coronavirus&apos;s don&apos;t tend to mutate rapidly,  + labs are working on this thing every single day.\n\nAs someone who has worked in labs, trust me when i say this sort of thing is identified quickly as peer reviews etc bring up red flags.\n\nThat is unless country&apos;s are sharing nothing',
#   '1258367387168116737': 'Of course he did, anyone who has ever worked for him is https://t.co/NvTOYeDVI4',
#   '1258367390150283264': 'Fresh greens, in quarantine! \n\n#spinach #tomatoes #onion #balsamic #covid19 #cleaneating https://t.co/4Mn5by3NKm',
#   '1258367390158671873': '@LancetLab_ZA may I find out why is it sooooo difficult to have a Covid-19 test done on my employees at your Lab in Mahikeng?',
#   '1258367390481514497': 'What a very informative graphic this is. Well done.\nA real pity that government mis-handling has made it this way!\nI would really have liked us to come out with fewest deaths. https://t.co/gbjt7mwrfy',
#   '1258367390607380480': 'Easy transition from climate change denial to corona virus deaths denial. https://t.co/ofpV8sKWrk',
#   '1258367390963970049': 'Revealed: the secret report that gave ministers warning of care home coronavirus crisis https://t.co/74Mhf4fpg0 @Mike_Padgham @DebraClaridge @paulapeters2 @blueannoyed @blacktriangle1 @AnitaBellows12 @mmaher70 @Dis_PPL_Protest @DPACSheffield @jshannontreacy @johnpringdns',
#   '1258367391404371969': 'Hey, here&apos;s an idea if you want to switch up your exercise regime! \n\nhttps://t.co/oShssW2pNn',
#   '1258367391458713600': 'They shot children! Not that should shoot adults but they shot babies on their summer jobs 😭😭😭. The rest of the world is doing take out and drive through with minimal hiccups while Americans scream about their rights being violated and are shooting people. https://t.co/a9mcLAObFZ',
#   '1258367391479857152': 'It&apos;s the only reference point Britain has because it&apos;s the last success the country had*.\n\n*or 1966 world cup bollocks https://t.co/3PCh80RNU9',
#   '1258367391521742850': 'I have some ideas for them. Put a plastic bag over your head and you will be safe from any germs. https://t.co/8clUWry3NI',
#   '1258367394130657280': 'Leave homeless on the streets when all is WELL (not healthy to live on streets, ever)\n\nBring them into confined space when virus hits (not healthy)\n\nAlso give them addictive substances (not healthy)\n\n“Health department”\n\nWhy gov should never run our healthcare\n\n👇👇 https://t.co/BYUx5KIeOw',
#   '1258367394197778434': 'Revealed: the secret report that gave ministers warning of care home coronavirus crisis https://t.co/XYG4x6OJGR',
#   '1258367394986315776': 'ODD how @CBSNews @KMOV aren&apos;t reporting the Project Veritas FAKE NEWS story .. I wonder why???  https://t.co/69nOkgdS2Y',
#   '1258367395233701890': 'Because they aren’t stupid like England xoxo Good on ya Scotland https://t.co/870uTuGQW7',
#   '1258367395338559488': 'Magic Leap’s death throes have little to do with\xa0coronavirus https://t.co/kObyyCxzDA',
#   '1258367395409940480': 'New study reveals blueprint for getting out of Covid-19 lockdown - News - UEA https://t.co/qJspzqwJD4 #UEA',
#   '1258367395707736068': 'And when a person with #COVID19 coughs their germs into the air, then what? https://t.co/NLrpCmyc6g',
#   '1258367395888013312': '@RandEnoch @Martinf683 @piersmorgan @MattHancock Because they generally have a highly-educated and pragmatic population who can generally be trusted with self-policed social distancing measures. Even then some bars &amp; restaurants are failing:\nhttps://t.co/9a0S7KbpLO',
#   '1258367397343326208': 'This little guy was tested for coronavirus yesterday, just two weeks before his first birthday! Praying the results come back negative. But, how cute does he look with a mask!?😷 https://t.co/LlS3Xpi0Ia',
#   '1258367397792296961': '#niet_in_journaal #US #military #COVID_19 Coronavirus survivors &quot;permanently disqualified&quot; from joining U.S. military, recruitment memo suggests https://t.co/bnKr7n31yC',
#   '1258367398144430080': 'Moderna shares surge after FDA approves coronavirus vaccine for phase 2 trial https://t.co/p1zSBB7BcY',
#   '1258367398564036609': '$MRNA now aims to start a Phase 3 study of its coronavirus vaccine candidate by this summer, sooner than the initial guidance for the fall. \n\nFDA approved IND for company to move into Phase 2, which will begin shortly, Moderna says.',
#   '1258367398723362816': 'wtf ? https://t.co/ov4YpTmsZJ',
#   '1258367398886998016': 'Using covid crisis recovery to transform the NHS\nhttps://t.co/bMXvPnQlSJ',
#   '1258367398928953349': 'Hey, @MaynoothUni - can you send us all a 6-pack of McGargles to help us cope too? https://t.co/XwekRzUTtr',
#   '1258367399893495809': '@HuffPostPol &quot;Widespread testing for coronavirus is unnecessary&quot; says the internet bot.\nIt’s just so fundamentally absurd that anyone can think this, is the response from a respected professor and medical analyst.\nTrump likes the bot&apos;s version so that becomes the truth; no checks no balances.',
#   '1258367399897845761': 'IRS Warns Public on COVID-19 Scams \nhttps://t.co/VHEVmyKbWy',
#   '1258367400556343301': 'The Coronavirus Circus Continues - LewRockwell https://t.co/f4eSMxOShQ',
#   '1258367400711524352': 'IRS Warns Public on COVID-19 Scams \nhttps://t.co/PpgATLiIrx',
#   '1258367402229841921': '@REBRwanda @RwandaTV @gtwagirayezu Us he says, covid19 were affected education sector but we appreciate the feedback about eLearning program for helping students to sharp our minds',
#   '1258367402238074880': '&apos;Political Virus&apos; Worst Than COVID-19 | Opinion | China Daily https://t.co/6b7pO7GyMN',
#   '1258367403580325890': 'The historian Paul Fussell once wrote of WWII “Chickenshit can be recognized instantly because it never has anything to do with winning the war.” There are a distressing number of local authorities eager to engage to chickenshit in the #coronavirus war. https://t.co/6fQtluzpdG',
#   '1258367403634970626': 'Hear from Covid-19 patient who had virus in\xa0December https://t.co/447QTWF5L0',
#   '1258367403660128257': 'We are scared because we cannot trust this Gov’t to do what is in our best interests! They are not bothered about how many people die, if NHS has correct PPE, if we are testing as many as we should be. They. Just. Don’t. Care! (Or at least that is what we feel). https://t.co/F2FTn9n9pN',
#   '1258367403895001088': 'As an assassination technique, this goes back to the Great Defenestration of Prague in 1419. Czech tradition and Soviet ambitions seems to have brought the technique into the Russian repertoire with the defenestration of Edvard Beneš in 1948. https://t.co/Ar8deWjki0',
#   '1258367345610850304': 'You may read the article summarizing the impact of COVID-19 on a corn and soybean farm on the farmDOC daily website.\n\nhttps://t.co/3gHoqy4fpv',
#   '1258367348005797889': 'Good news for the dairy industry #dairyfarming https://t.co/fjF3FsE9TD',
#   '1258367348647616512': 'You, @realDonaldTrump , are personally responsible for all 73,000+ coronavirus deaths, not China.',
#   '1258367349217988608': 'https://t.co/rOgCrhBjLX https://t.co/q3kw9vtWxv',
#   '1258367349914243072': '#Coronavirus: Juventus Forward, Paulo Dybala Is Now Free\xa0(Photo) https://t.co/jUtwqKThsJ',
#   '1258367349922713602': '@piersmorgan All this simpering.\n\nWe won&apos;t beat Covid-19 by pretending that an extended lockdown will get rid of it, either.',
#   '1258367352439214080': 'What, exactly, do the COVID-19 protesters want? | https://t.co/UsbX7eCwDJ https://t.co/iwhX3CtyCB',
#   '1258367353580130310': 'Pence: ‘Beyond the pale’ for Virginia State to Sanction Church For Holding 16-Person Service\n\nhttps://t.co/bw6iChk40j\n\nDownload The Epoch Times app to see our exclusive Coronavirus coverage and daily updates:https://t.co/GjSbhVPtq4',
#   '1258367355975012353': 'The Kenyan government plans to impose a 1.5% digital tax on digital transactions, according to proposals in the finance Bill 2020, in a bid to cash in on the evolving industry taking off amidst the COVID-19 pandemic.\n\nhttps://t.co/Z4n6dI8mYx',
#   '1258367356000186370': 'Louisiana nurse tells Trump that coronavirus protective gear is &apos;sporadic.&apos; He pushes back. | Coronavirus | https://t.co/mWHV6eF1ro https://t.co/ocauzFUx4P',
#   '1258367356738375681': 'MGM’s Hornbuckle warns of thousands of layoffs in letter to employees amid coronavirus shutdown https://t.co/u8QcbdXgP2',
#   '1258367357124313089': 'I totally agree @piersmorgan, I’d hate this last 6/7 weeks to have been for nothing l. I’ll be proper pissed off if we go backwards. Let’s be patient FGS. STAYING IN ISNT KILLING US. GOING OUT COULD. \n#nHS ❤️ https://t.co/iAafYsgq07',
#   '1258367357547929601': '#NeverMoreNeeded https://t.co/cg2CfJIwMr',
#   '1258367358235803648': '@Strandjunker Current Coronavirus Deaths... continues to rise. https://t.co/J0JXUAvydm',
#   '1258367358487404547': 'Very interesting read in the Globe today.  We treat instead of prevent.  https://t.co/otcYShf3Mn',
#   '1258367360051879936': 'IOM Egypt donated personal protective equipment (PPE) and #COVID19 awareness raising materials to Giza Governorate. in order to be used by 700 national healthcare leaders during their work on raising awareness among the population, which covers 22 villages in #Giza. https://t.co/Jox3sHcBGh',
#   '1258367360756600837': 'Volta Regional Health Directorate to enhance testing after surge in COVID-19\xa0cases https://t.co/Nnqamtqnif',
#   '1258367361100513281': 'As more people work from home during the #COVID19 crisis, remote meetings have become a vital part of the workday. #MicrosoftTeams makes meeting remotely easier. Watch this video to see how! https://t.co/P8d00Ai7JR',
#   '1258367361159180289': '#Coronavirus: Juventus Forward, Paulo Dybala Is Now Free\xa0(Photo) https://t.co/YF9Kppj4Yz',
#   '1258367361574244352': '&quot;The first batch of staff were trained at French labs,&quot; she said, adding that its equipment is tested every year by internationally recognised third parties.\n\nhttps://t.co/o7vSmbt76r',
#   '1258367362061021190': 'Coronavirus is 4.2x more likely to kill you if you’re an ethnic \nStale, pale males are at driving many technological advances\nCountries at cutting edge: US, UK, Germany\nBut hey, @guardian will consign whitey to history \nTruth! Nature is not egalitarian\n\nhttps://t.co/5Xjeae6p2G',
#   '1258367362245505024': 'Sask. government pressed to release COVID-19 data https://t.co/jW4vpPCbIk',
#   '1258367364174942217': 'Visit our website for updates and how Bridgehouse can support your business during this pandemic. \n\nhttps://t.co/sBvYZvovew\n\n#CompanySupport #BHCSecretaries #BusinessSupport #ContactUs #covid19businesssupport https://t.co/x9VKPeHgIS',
#   '1258367364808060928': 'How one of #BigPharma’s most corrupt companies plans to corner the #COVID19 cure market https://t.co/3i5vBic5xL',
#   '1258367365030522880': 'But everyday at 1100 Hours, Ministers and Security officials hold Press Conferences at the @UgandaMediaCent.\nIs the Minister of Presidency just incompetent to inform @Parliament_Ug of the efforts made to streamline the various directives and their implications!\n#COVID19',
#   '1258367365781356545': '#Newsnight https://t.co/QxA8MbQp79',
#   '1258367366343376898': 'Volta Regional Health Directorate to enhance testing after surge in COVID-19\xa0cases https://t.co/lpP1JQfCBq',
#   '1258367366485942277': 'Coronavirus Survivors &apos;Permanently Disqualified&apos; from Joining U.S. Military https://t.co/r2cbIaV4LV',
#   '1258367366666293248': 'The FG is a scam, now they have opened an account with one of the major banks and are asking people who want to support them to eradicate Covid-19 to make donations into the account. This is interesting.',
#   '1258367368021057536': 'Build Immunity During COVID-19 by focusing on what you can control, your strengths. Learn how to MAXIMIZE YOUR POTENTIAL. Build immunity or assist others from job loss, broken relationships, and life constraints. Sat, 5/9 at Noon. #NAAAPOrlando\n\nRegister: https://t.co/v7cldmHmoR https://t.co/etSAV3v8P2',
#   '1258367368331436032': 'The Colorado #COVID19 Relief Radiothon starts now! All day, we&apos;re raising money with @RisnerupF, @bankofcolorado and @fixit_247 to help support @FoodBankRockies, @BGCMetroDenver and @VOAColorado. \n\nMake a donation here! https://t.co/GccRvFpqgo\n📻 https://t.co/MoMgradpHa https://t.co/r1tniHuEEc',
#   '1258367368453148676': 'On this National Day of Prayer, we send out some much need prayers to our country #MAGA #KAG #COVID19 ✌️🇺🇸✝️ https://t.co/YjfVbyFWoe',
#   '1258367368654438403': 'BBC News - Coronavirus: Aer Lingus review after packed flight complaint https://t.co/9XDKwzVkzR',
#   '1258367368725659651': 'That was not an insult!  I’ve seen many insults in my time and that wasn’t an insult.  People need to get their facts straight https://t.co/sNfB7PNR2r',
#   '1258367368775917570': '@thehill @TheHillOpinion Trump’s Ridiculous Behavior about Covid19 at Pandemic Briefings Battles https://t.co/4Gjy5tQ4XI https://t.co/SOdeZ8bHQH',
#   '1258367368998330368': 'Spotted by our man about town @GuideRussell 😷 #art #graffiti #urbanart #artist #graffitiart #mural #streetarteverywhere #steetart #tallyholondon #banksy #covid19 #coronavirus #london https://t.co/9qQz88Uew4',
#   '1258367369556234240': 'Today would have been local election day in England, postponed untill next May because of the Coronavirus outbreak. Next year now sees something like 87 councils, including the counties, to be elected and almost 3,800 seats up for grabs. It will be pretty bonkers \n\n.',
#   '1258367369598193664': '@laurajkirkland @piersmorgan https://t.co/TvCkjpd6pn 🙄',
#   '1258367371078590469': 'PM India \nWe support Modi ji since he is taking more interest in  controlling covid19\nWe will be free from  virus before july2020',
#   '1258367372953600005': '@newhollandbrew I ordered some of this and it was great and arrived quickly. Please consider using different packaging, though. Uline’s owner uses her $ to push policies that are bad for your neighbors in WI. https://t.co/zgDbmnN8jx',
#   '1258367373666668544': 'Despite the citizens cries and pleads for palliatives, what buhari led government could do was to send everyone out on the street while the covid-19 pandemic is still at large in Nigeria, for this reason #IstandagainstBuhari yes #IstandagainstBuhari #RevolutionNow https://t.co/O7dYsCgMg0',
#   '1258367374153199622': 'People are taking the drinking dens into the residential estates especially in the slums of Obunga, Manyatta and Nyalenda where the police does not do patrol during curfew #StaySoberStaySafe. https://t.co/TlN7A5MFbo',
#   '1258367374434197505': 'Watching Aljazeera. Report says Blacks in UK are four times more likely to die from Covid19 than whites. Wonder why this is?',
#   '1258367374786547713': 'Majority Of New Coronavirus Cases In New York Are From People Staying At Home—Not Traveling Or Working https://t.co/bkr8VdmeOv',
#   '1258367374908104704': 'New report from @MoodysInvSvc demonstrates that additional funding is needed for states to help weather the #COVID19 created budget storm https://t.co/TQx9tFSvGB',
#   '1258367376741085184': 'COVID-19 in Canada #coronavirus https://t.co/hcLrgHBcGF',
#   '1258367376938143744': '&quot;We may see even further peaks of this virus.&quot;\nDr Andrew Goodall said the NHS is prepared to see more peaks in coronavirus cases when we begin to ease out of lockdown https://t.co/Tq2xIFfKsd https://t.co/JvWCml175b',
#   '1258367377386778624': 'Is Canine Coronavirus Vaccine Proof that COVID-19 Vaccine Should Exist? | @scoopit https://t.co/m3pRaxnj0c',
#   '1258367377546383361': 'Fucking hell......\n\nHas Sir Keir Starmer been hacked by @jeremycorbyn ?\n\n🤣😂🤣😂😂🤣😂 https://t.co/GCYUcXR8mx',
#   '1258367462418104320': 'Oi,  Piers. Good job we are not lifting lock down as Pakistan will do on Saturday.  Wait for those unchecked flying over here. https://t.co/pyJ8jjodXw',
#   '1258367462531313664': 'They Are Giving You Death and Calling It Liberty https://t.co/UiVpxbKRPE via @RollingStone',
#   '1258367462862618624': 'COVID-19 or Corona virus has ignited the old debate of religion vs science as its faster spread has been traced to congregation of religious faith groups across many communities amidst a worldwide call for social distancing in order to contain the spread of the virus.',
#   '1258367463282049025': '‘An Anvil Sitting on My Chest’: What It’s Like to Have Covid-19 https://t.co/fonNUZYkXY #stayaparttostaytogether',
#   '1258367465534480384': 'Read how SC&apos;s healthcare and higher education\nleaders are teaming up to defeat COVID-19 and more in SCBIO&apos;s Newsletter: https://t.co/6QPoZvLSlK',
#   '1258367465916190721': ': https://t.co/moe6xLnBnR',
#   '1258367466180186115': 'First covid19 death the US officially recorded Feb 29th (there were deaths before this date) I suspect even in Jan\nSo in 90 days 75,000 Americans are Dead \nThat&apos;s with us staying home \n\n#COVID19',
#   '1258367466364964866': 'At last some good news https://t.co/1JvIc4zkJj #COVID19',
#   '1258367467702726657': 'Truth is #covid19 isnt going to disappear, life needs to go on, the govt can do nothing if we lose our jobs, We have worked hard abroad, dont take it away from us now🙏🙏 let us leave. #NRIsStranded listen to us #Lockdown3 #resumeinternationalflights @PMOIndia @HardeepSPuri',
#   '1258367468814434304': 'Good luck with the result https://t.co/kiXGowNdNp',
#   '1258367469934313473': 'To keep coronavirus patients off ventilators, Lehigh Valley hospitals turn to new treatments and drugs \n\nREAD MORE: https://t.co/qVQ8VDOZJL\n\n#cdc #coronavirus #covid19 #mers #outbreak #pandemic #sars #ViralOutbreak #virus #who* https://t.co/DZDOehdEpI',
#   '1258367469946798080': '@realDonaldTrump DR.FAUCI HIS HE INVOLVED IN THE CORONAVIRUS PANDEMIC FOR HIS OWN INTEREST?',
#   '1258367470223622146': 'Xd https://t.co/eX1IFFgdxj',
#   '1258367471104348160': '@thehill Trump’s Ridiculous Behavior about Covid19 at Pandemic Briefings Battles https://t.co/4Gjy5tQ4XI https://t.co/4Yo2m3AaHS',
#   '1258367471515586562': 'All 400,000 gowns flown from #Turkey for NHS fail UK standards @guardian #coronavirus https://t.co/rqsXTE21Th',
#   '1258367471733673985': 'The whole country seems to be running 5K a day and doing quiz’s every night according to instagram. By the end of this we SHOULD be the fittest, most intelligent country in the world and have enough banana bread to feel everyone 🤷🏼\u200d♂️ #COVID19 #justathought #imnotrunning',
#   '1258367471905640448': 'By Prof. Anwar Alam, Senior Fellow at the PPF Under COVID-19 Special Edition\nhttps://t.co/XZHCM3G1sQ',
#   '1258367472350253056': '@tperkins So how come all of your prayers haven’t stopped Coronavirus?',
#   '1258367473432354816': '@andy_176382 @RealJamesWoods No, Cuomo sent Covid patients back to nursing homes, along with a supply of body bags: https://t.co/xjazlaZmyq',
#   '1258367473952440320': 'https://t.co/1PZd85PNz9',
#   '1258367474560462850': 'I&apos;m considered essential, but I don&apos;t claim to be a hero. Just doing my part to help. The detail is great, overall a great looking kit. https://t.co/sP3626BP8g',
#   '1258367475068043264': 'Llamas Will Become Coronavirus Heroes https://t.co/gRfICyItyQ',
#   '1258367475172999174': '“No longer sandwiched between bankers and office workers, the millions of people whose labor the city has always relied on are more visible than ever.” https://t.co/qHO78rCqkY',
#   '1258367475420467206': '7 Brick and Mortar Business Adaptations We’ve Seen for COVID-19\nhttps://t.co/4EvV5QtD9K',
#   '1258367475756027904': 'A new report from Construction Coverage is looking at small businesses nationwide and how #COVID19 has impacted them even before the pandemic started. Details ahead on @FOXNashville at 7:13a.',
#   '1258367475823136769': 'Roundtable Discussion with Dr. Judy Mikovits | Dr. Rashid A Buttar\nhttps://t.co/xtSCTbo4H3\n#eNCAMustFall  #propoganda for spreading fear. #coronavirus',
#   '1258367475936374786': 'Monroe County elections officials gear up for a change in the June 23 election, now that a judge has allowed the Democratic Presidential Primary to move ahead.\nhttps://t.co/HvQd6zP3j5',
#   '1258367477551116291': 'An easy to read guide from Inclusion Ireland on minding your mental health during #COVID19 \n\nhttps://t.co/rObI6WPsmZ',
# ...
#   '1269647446029864960': 'Cigna Newsroom | America&apos;s State of Mind: Use of Mental Health Medications Increasing with Spread of Coronavirus https://t.co/ijevNJ1k0l  @Cigna @ExpressScripts\n\n#Cigna #MentalHealth  #CoronaVirus #MentalHealthMedication',
#   '1269647446252150785': 'An interesting guide from #PwC on the challenges that many #media industry businesses may be facing due to #COVID19 and how to respond to them: https://t.co/c85XnCVt6B #COVID #COVID-19 #mediaindustry',
#   '1269647446487052290': 'Where was all this outrage when VE Day parties like this were gathering? Stop using Coronavirus as a way to air your opposition to the Black Lives Matter movement. https://t.co/eqOcsqPmoD',
#   '1269647447061643265': 'Quick question.. is racism over? https://t.co/sLeeDFxERO',
#   '1269647448525475843': 'In Ohio, the Department of Job and Family Services reports manufacturing employment dropped 13.79%. #Business #BusinessNews #Manufacturing #Coronavirus https://t.co/rVSy0086P5 https://t.co/WcnWpI2vVH',
#   '1269647449183920128': '@Polly12YT @Haruka_Black1 But all protestors are participating in the spread of covid-19 which on twitter up until a week ago was “literally murdering others”',
#   '1269647449251078144': 'This is distressing. https://t.co/012nq3HPW0',
#   '1269647449347555328': 'So looking forward to talking with @adira_t @sivasaijeeva and Linda @GALAarchives tomorrow afternoon. Please join us live - or to listen again! https://t.co/6UDnhVlIXY',
#   '1269647449494376449': '&quot;19 out of 40 rescue divers at a fire station in Stockholm are not allowed to dive as they have lung damage after covid-19&quot;\nhttps://t.co/e6t7iRHPFw\n\nSwedish government&apos;s strategy to get everyone infected is a war against its own population. https://t.co/MbGG672PJU',
#   '1269647450329014278': 'Boris Johnson&apos;s 11 fatal errors in handling coronavirus crisis which cost lives https://t.co/IcJSNdkspZ',
#   '1269647450601635843': '@thomaskaine5 Covid19 is spiking in my town.  I’m staying in and wearing a mask when I have to go out.',
#   '1269647451012530177': '&apos;All-pet private jet&apos; to reunite animals stranded during coronavirus pandemic\n\nhttps://t.co/VGcN7Iu9Pn',
#   '1269647451658416129': '#NewsAlert | 191 fresh COVID-19 cases have been reported in Haryana taking the total tally to 4143. https://t.co/vu7bgfzxMY',
#   '1269647452904099840': 'Mustafa Centre, Tampines Mall and Geylang Serai market added to list of places visited by Covid-19 cases https://t.co/pUV0oTgfBB',
#   '1269647454032429057': '#BlsckLivesMatter until we kill everyone with Coronavirus. Stay home people! https://t.co/wDEgEdOmyx',
#   '1269647454376427522': 'We&apos;re seeing, in real time, the result of politicizing masks.  Look at all these red states with exploding coronavirus outbreaks. https://t.co/zSif9FAMfz',
#   '1269647454808551425': 'BBC News - Coronavirus: Lockdown delay &apos;cost a lot of lives&apos;, says science adviser\nhttps://t.co/wYt4mE8Jh2',
#   '1269647455701753856': 'Religious places, shopping malls, restaurant hotels and offices which remained shut due to COVID-19 lockdown, set to reopen from tomorrow. https://t.co/lq571wQ6Yk',
#   '1269647458625294343': 'Data from Knox County shows a continuing rise in cases, going from 89 to 95 active cases since yesterday. (Thanks for the advice on the data y’all) https://t.co/uyvAo3EFeq',
#   '1269647458914664449': 'covid-19 sucks. https://t.co/EMFlpMI14T via @YouTube',
#   '1269647459883589632': 'Everyone stay safe out there and remember #BlackLivesMattter 🖤 https://t.co/cA4HcM2Zup',
#   '1269647460491833347': 'With Kashmir valley witnessing surge in number of Covid-19 cases,Doctors\xa0Association Kashmir (DAK) on Sunday said reopening of economic activities in presence of high degree of virus transmission would be risky.',
#   '1269647460583931905': 'So may hospitals in #Delhi are not accepting #COVID19 patients. I have read about so many cases by patients are their relatives. Whats @ArvindKejriwal doing? Just giving speeches. Shame on @ArvindKejriwal',
#   '1269647461162737664': '#CoronaVirusindia Bhopal administration decides to not reopen places of worship from tomorrow. #CoronaVirus #Covid19 #pandemic #CoronaVirusUpdates #bhopal #MadhyaPradesh #religion',
#   '1269647461896777729': 'This comes after a private meeting w/ members of Gov. Gavin Newsom&apos;s staff who revealed that in #California, the #coronavirus did not spread first from a nail salon, unlike what the governor said in May. On #Facebook, nail techs echo one another, saying they’ve been “waiting...&quot;',
#   '1269647462320369664': 'Imposing lockdown to prevent coronavirus is causing many problems for students studying in all kinds of educational institutions across the country.\n#GeneralPromotion4BihariStudents',
#   '1269647462492323841': '199 more cases take coronavirus tally to 4,659 in Andhra Pradesh\nhttps://t.co/HSTQOHgB48',
#   '1269647463029317633': 'The End of College as We Knew It? https://t.co/F8uz3GTqSa Colleges and universities are in trouble — serious trouble.  We need, writers, philosophers, historians.  Not sure we&apos;re going to get that.',
#   '1269647463117357056': '#Apple Releases #Apple Maps Mobility Data Trends Tool to Help Mitigate COVID-19 Spread\nhttps://t.co/DWWgMnkAA9',
#   '1269647465629675520': '@CTVNews Virus is BS quit testing https://t.co/MVN9vOm9J4',
#   '1269647465634029570': '@Tandy91573262 @pure_squall9 @lilym326 @the_resistor @realDonaldTrump Yes, Cuomo signed an order to make Nursing Homes take in Covid19 patients. Literally killed all your Grandparents. But hey it&apos;s &quot;tRumps&quot; fault right? \nhttps://t.co/ZlFc2nbIwN',
#   '1269647466812641281': '&quot;When it comes to coronavirus and health concerns, building owners and operators need to avoid making promises they can’t keep.&quot; Read more on @GlobeStcom https://t.co/0rJsrXpDhu #SIOR #CRE #COVID19 #reenty',
#   '1269647380149911552': 'Three unions under Ukhia upazila and Teknaf municipality in Cox&apos;s Bazar district -- areas inhabited by #Rohingya refugees from #Myanmar -- have been declared red zones to prevent the spread of the #coronavirus.\n\nhttps://t.co/cgP1jqBVpw',
#   '1269647380183429123': '@10DowningStreet Get coronavirus, drive to family, stay in an illegal house, test eyes, visit castle, pass virus on, go back to work, change online blog to pretend that you are clever, destroy democracy, sell the NHS, make millions off no deal brexit, flood the UK with poisonous food, run away.',
#   '1269647380409913345': 'Even greater anti-#COVID19 protection by adding Povidine Iodine to the Hypertonic Saline Douches as per this @UHSFT ENT Department protocol! https://t.co/jBVdXkn4E4',
#   '1269647381013893123': 'The Observer view on the government&apos;s handling of the Covid-19 crisis #BorisJohnsonHasFailedTheNation https://t.co/CntyxkXIlu @MattHancock why not work collaboratively with other parties?',
#   '1269647383924744192': 'My heart goes out to all of you who have had covid-19 impact their health, the health of their loved ones and lost loved ones because of it. 🕊',
#   '1269647384755277825': '#Covid19 bot \n#COVID19 last 5 days stats #Meghalaya\nDeceased Cases trend\n02-Jun - 0\n03-Jun - 0\n04-Jun - 0\n05-Jun - 0\n06-Jun - 0\n#CoronavirusPandemic #COVID19India #coronavirus #IndiaFightsCorona #StayHome #StaySafe',
#   '1269647384772071424': 'How very on brand for the TRUMP ORGANIZATION. https://t.co/3V8HUM5evu',
#   '1269647384977584130': 'As part of government&apos;s continued COVID-19 suppression plan, this is what you can do in Grand Cayman as of today (June 7, 2020). https://t.co/xdAzyKyrIl',
#   '1269647385468325893': '@Mr_FuegoYm https://t.co/sAXN5Cw3bY',
#   '1269647387590459394': 'You can&apos;t expect only the leaders to save you from covid-19 if you don&apos;t follow the protocols to save yourself.',
#   '1269647393500299269': '@matthancock @grantshapps instead if 14 day quarantine on entry 6 months too late why don’t we have a rapid PCR testing system, which exists in more civilised countries than the UK?\n#Coronavirus',
#   '1269647396457402373': 'Total hospitalizations down 36% since May 20th. https://t.co/DT9I0oOces',
#   '1269647396767760384': 'Interesting study out of China on the impact of COVID-19 on college students: &quot;In further analysis, the study also determined that factors such as economic stability and delayed studies increased anxiety levels among students&quot;\n\nhttps://t.co/qmH26RTg5J',
#   '1269647396893528066': 'Daje Bruno!  Latour: &apos;This is a global catastrophe that has come from within&apos;\n\nhttps://t.co/Vq2re0WZAZ',
#   '1269647397027790852': '@jk_rowling World is focussing of other serious issues #COVID19 #BlackLivesMattters #riots2020\nTry uniting people or helping others',
#   '1269647398634217473': '@MiLOKMAT Under #WorldBestCM today Maharashtra overtook China in total #coronavirus cases to 85975+ cases with 3060 deaths! \nNow @mybmc new guidelines asking Mumbaikars with Corona to stay at home quarantine! BKC, Goregaon,MumbaiSportClub temporary hospitals goes wasted ? @CMOMaharashtra ?',
#   '1269647399078825985': '@realDonaldTrump shd watch how @globaltimesnews of #China under World&apos;s No1 Criminal #XiJinping is playing politics on #BlackLivesMattters .\n\nUgly politics in  US in name of #BlackLivesMattters .\n\nJoblessness created by  #ChineseVirus #WuhanVirus &amp; sinister #Chinese r behind it https://t.co/f5rMLXW9dO',
#   '1269647399217254403': 'In 2014, I proposed that all of the city&apos;s buses should be free as an alternative to expanding streetcar. Last year, the city said they would implement free buses, but they never found the money to do that, and next year, because of COVID19, the city will have to cut their budget',
#   '1269647401129836544': 'The only way we will ever win over racism is to show them that we love ourselves first. Please take the time to tell every black person you love them. #BlackLivesMattters #BlackLove #COVID19 #',
#   '1269647401469575169': 'Today is the final episode of #CJAD800&apos;s #COVID19 special coverage. Join me from 12-1pm with special guests Dr. Mitch Schulman, Scotia Wealth&apos;s Arnie Zwaig, and for the final half hour, @mtlgazette health reporter @Aaron_Derfel. As of last check @francoislegault won&apos;t be joining.',
#   '1269647402316824578': 'The latest Veronica&apos;s Daily Pick &amp; Mix! https://t.co/ttkxL1ydpC #covid19',
#   '1269647403214389248': '#CoParenting During #Coronavirus Has Made Families More Flexible Than Ever. #Divorcedparents fear that the #pandemic will up-end their #custodyarrangements, but that&apos;s not what&apos;s happening on the ground https://t.co/NlXfGe6xtC by @goodhousemag shared by @WeinbergerLaw',
#   '1269647403273129990': 'Founder of Global View Discusses Investing Post-Coronavirus\n\n#FinancialPlanning #RetirementPlanning #Retirement #Yeahthatgreenville #Coronavirus #Investing\n\nhttps://t.co/lP6OI0E3ZK',
#   '1269647404619481089': 'Fox Business looks at the emerging housing market, returning from the COVID-19 crisis. More @ https://t.co/kuzkaUggLJ',
#   '1269647406381096961': '#CCP_is_terrorist #CCP #China #ChineseVirus #NationalSecurityLaw #HongKong #HongKongPolice #HongKongProtests China Tribunal 2019 https://t.co/zRlWeqjutX petition #UNHRC #shameUN  https://t.co/i1BCpTB0ya #StandUp4HumanRights #StandWithHongKong #StandwithHK #StandTogether #COVID19 https://t.co/zNQef1VCEM',
#   '1269647406842310657': 'Well I am sure convinced! #ChinaLiedPeopleDied https://t.co/6j63tZjVwn',
#   '1269647407668776960': 'agreed but there’s a whole bunch of ignorant ppl out there who don’t care... https://t.co/FhVHE09tvo',
#   '1269647408520036353': 'After The Covid-19 Panic: Three Lessons For Business https://t.co/rLluEQ7D2r',
#   '1269647410130632704': 'With this antiviral fabric coating, your clothing could protect you from COVID-19 https://t.co/DB8PrStQ7W',
#   '1269647412349382656': '@realDonaldTrump Didn’t Trump say Covid-19 cases in the US would “soon be down to zero?”  You don’t wanna play this game, monster.',
#   '1269647412869476352': 'The impeached one said it would be gone by April\n\nWW1 deaths is his next milestone...116K is very close\n\n United States\nCoronavirus Cases:\n1,991,799\nDeaths:\n112,137\n\nhttps://t.co/0ZDO5cw0tw',
#   '1269647412920045573': 'St John’s need this money more than ever right now! They have stepped up their services to help the NHS through the Covid-19 crisis, despite having most fundraising events cancelled. To help support an amazing charity, please join the quiz on Friday and donate what you can! X',
#   '1269647413288955904': '@holyterrainbri don’t incite this movement in Japan right now without being here there are alway risks that COVID-19 situation get worse and Japan has the highest number of old population. and the efforts that numerous company and people put during lock down will be waste.',
#   '1269647413846949889': 'Antibody injection against coronavirus could be ready next year https://t.co/MezxM8XMAh via @MailOnline \nSAY NO SAY NO SAY NO',
#   '1269647414673186821': '&apos;It feels endless&apos;: four women struggling to recover from Covid-19 https://t.co/MxhCmetUX1',
#   '1269647416019599361': 'Egyptian father to stand trial on charges of forced FGM of three daughters: Girls were allegedly told they were to have Covid-19 vaccinations but were cut by doctor after being sedated. The procedure was banned in 2008 and criminalised in 2016. via /r/wo… https://t.co/OVyyC726XG',
#   '1269647416682143744': 'https://t.co/XQuyms2R1W https://t.co/6Rn5wPhJQr',
#   '1269647416694882305': '[#COVID19] 🇬🇷 Greece prohibits flights from Qatar. \n\n🦠 A Qatar Airways’ aircraft landed in Athens with 96 passengers infected by the COVID-19. \n\n❗️ Following this event, Greece decided to refuse all flights from Qatar. https://t.co/NN3LdKAgc9',
#   '1269647417424646145': 'Brazil govt tweaks virus death toll: Brazil’s government has stopped publishing a running total of coronavirus deaths and infections in an extraordinary move that critics call an attempt to hide the true toll of the disease in Latin America’s largest nat… https://t.co/nYX3vUkBA4',
#   '1269647418645270533': 'For #hospitals and #health systems on the front lines of #COVID19, ensuring a full and healthy staff, along with new policies and procedures to keep patients safe is critical for a successful recovery. Learn more here: https://t.co/drNGjzvD0W #healthcare #recovery https://t.co/b1lo1S21Je',
#   '1269647419320537089': 'Appreciate Washington Post mentioning James Carville&apos;s  piece in @Philanthropy \nhttps://t.co/XEaI7bbAPq\nYou can read it here: https://t.co/yhozYSkXST via @Philanthropy',
#   '1269647419664404480': '@asare_ym @shaunking I noticed that people of African descent are infected more  in countries with a large European population.\n\n#COVID19 #COVIDIOT #GeorgeFloydProtests',
#   '1269647421082087425': '#WhitePaper China has provided free medical treatment for #COVID19 patients. As of May 31, the medical bills of 58,000 inpatients with confirmed infections had been settled by basic medical insurance, with a total expenditure of about $190 million. https://t.co/WmpIMTRE60 https://t.co/yFIa4I07Iq',
#   '1269647422105374722': 'GOP Voters Against Trump\xa0is lashing out against what’s filling trump’s time during the COVID-19 pandemic and nationwide anti-racist protests: “Hiding in a security bunker. Watching his shows. Afraid. Alone. Not a leader, not a president.” #presidentCOWARD  https://t.co/3fjcGnt0TL',
#   '1269647422252216320': '@DailyMailUK Coronavirus likes this!',
#   '1269647424831840257': 'China would make a coronavirus vaccine.\nhttps://t.co/FG0aYdmGA3 https://t.co/cNmyLra1es',
#   '1269647426996092929': 'Displaced people are the most vulnerable to the threat of #COVID19. We need an immediate ceasefire in Yemen to save lives. #UNWomen #OSESGY #GroupofNine #unwomenyemen #YemenCantWait #StopWar #Yemen4Yemen\n \nhttps://t.co/MqZhCzvfIB https://t.co/cQe5VSdSnN'}}

# %%
lens = []
for key in english_tweets_sample:
      lens.append(len(english_tweets_sample[key]))
assert sum(lens) == 697, f"Something is wrong! You should have 697 total tweets,\
                                                                        not {lens}."

# %% [markdown]
# ## 6. Create the XML file
# The function below writes an XML file to the current directory depending on the kind of data supplied to it. If the data given is ```sample```, the output is XML of sample data whereas if the ```full``` data is given, the output is XML of full data.

# %%
# creating xml file
def create_xml(classified_tweets, data_type='sample'):
    """Function returns a list of texts containing all the tweet texts in the text

    Args:
        tweet_file (str, mandatory) : a tweet string from which text need to be extracted.
        data_type (str, optional) : a tweet string from which text need to be extracted
    Returns:
        list : List of texts in a tweet text"""

    accepted_dataypes = ['sample', 'full']
    assert data_type in accepted_dataypes, "Enter a valid data type!"

    if data_type == 'sample':
        file_name =  './sample_result.xml'
    else:
        file_name = './30914345.xml'

    with open(file_name, 'w', encoding="UTF-8") as f:
        f.write(f"""<?xml version="1.0" encoding="UTF-8"?>\n""")
        f.write("<data>\n")
        for tweet_date, tweets in classified_tweets.items():
            f.write(f"""<tweets date="{tweet_date}">\n""")
            for tweet in tweets.items():
                f.write(f"""<tweet id="{tweet[0]}">{tweet[1]}</tweet>\n""")
            f.write(f"""</tweets>\n""")
        f.write("</data>\n")

create_xml(english_tweets_sample)

# %% [markdown]
# ## 7. Unified function to extract english tweets
# Here we create a unified function that can extract all the english tweets from a directory containing text files of tweets. The input to the function is the ```file_path``` to the directory and the ```data_type``` we want to process. Note that ```sample``` is a default argument for the function, ie, if we give the path of full files and do not mention the ```data_type``` to be ```full``` the output XML is created using sample data. This is because running full data takes a lot of compute and we want to avoid accidental runs of this function. <b> So unless the keyword argument data_type is equal to "full", the full data is not processed. </b>

# %%
def get_english_tweets(file_path, data_type='sample'):
    """Function returns a list of texts containing all the tweet texts in the text

    Args:
        tweet_file (str, mandatory) : a tweet string from which text need to be extracted.

    Returns:
        list : List of texts in a tweet text"""
    
    list_of_texts = read_files(file_path)
    tweet_data = grab_data_tag(list_of_texts)
    tweets = get_full_tweets(tweet_data)
    classified_tweets = get_date_dict(tweets)
    create_xml(classified_tweets, data_type)
    
    if data_type == 'sample':
        message = 'Check your current directory for the output XML named sample_result.xml'
    else:
        message = 'Check your current directory for the output XML named 30914345.xml'
    return message

# %% [markdown]
# ## Process the full data
# We now run the unified function ```get_english_tweets``` on the full data and this returns an XML file in the current directory.

# %%
# Run the unified function on full data
file_path_full = './30914345'
get_english_tweets(file_path_full, data_type='full')
# Out:
# 'Check your current directory for the output XML named 30914345.xml'

# %% [markdown]
# ## References
# ( Referencing style : [APA 6th Referencing Style Guide](https://aut.ac.nz.libguides.com/APA6th/websites ) )
#
# * ```os``` library methods. os documentation : os.path, os.listdir. Retrieved August 22, 2020, from
# https://docs.python.org/3/library/os.html
#
#
# * ```re``` library methods. re documentation : re.sub, re.match, re.findall. Retrieved August 25, 2020, from
# https://docs.python.org/3/library/re.html
#
#
# * ```langid``` library function. langid documentation : langid.classify. Retrieved August 27, 2020, from
# https://pypi.org/project/langid/1.1.5/
#
#
# * Jan Goyvaerts (2013-2020), How to build regular expressions. Retrieved September 7, 2020, from
# https://www.regular-expressions.info/
#
#
# * XML's predefined entities (17 July 2020). Wikipedia, the free encyclopedia. Retrieved September 8, 2020
# https://en.wikipedia.org/wiki/List_of_XML_and_HTML_character_entity_references#Predefined_entities_in_XML
#
#
# * Surrogates and Universal Character Sets (13 June 2020). Wikipedia, the free encyclopedia. Retrieved September 9, 2020, from https://en.wikipedia.org/wiki/Universal_Character_Set_characters#Surrogates
